# %%
import pandas as pd
import numpy as np
import time
import datetime
from tqdm import tqdm
import random

# %%
data = pd.read_csv('bolha_flats_all_info1-49_14-03-2021_20-55-58.csv')

# %%
data= data.drop('Unnamed: 0', axis = 1)

# %%
data.head()
# Out:
#    Šifra oglasa          Objavljen           Do poteka še  \
# 0       6523968  14.03.2021dne18:49  \n29dni,22h,33min.\n
# 1       6523894  14.03.2021dne18:39  \n29dni,22h,24min.\n
# 2       6523589  14.03.2021dne18:07  \n29dni,21h,52min.\n
# 3       6523431  14.03.2021dne17:47  \n29dni,21h,32min.\n
# 4       6523190  14.03.2021dne17:16   \n29dni,21h,0min.\n
#
#   Število prikazov oglasa             Cena   Vrsta cene Posredovanje  \
# 0                 57-krat  \n\n192.000 €\n  Skupna cena       Prodam
# 1                 29-krat  \n\n134.500 €\n  Skupna cena       Prodam
# 2                 33-krat   \n\n29.500 €\n  Skupna cena       Prodam
# 3                 34-krat  \n\n120.000 €\n  Skupna cena       Prodam
# 4                 23-krat  \n\n180.000 €\n  Skupna cena       Prodam
#
#                                           Lokacija     Umeščenost stanovanja  \
# 0                 Savinjska, Celje, Slavko Šlander  V večstanovanjski stavbi
# 1      Osrednjeslovenska, Ljubljana Center, Center  V večstanovanjski stavbi
# 2                          Gorenjska, Tržič, Tržič  V večstanovanjski stavbi
# 3  Savinjska, Slovenske Konjice, Slovenske Konjice  V večstanovanjski stavbi
# 4  Osrednjeslovenska, Ljubljana Bežigrad, Bežigrad  V večstanovanjski stavbi
#
#   Nadstropje  ...  Neto površina Leto izgradnje* Leto zadnje prenove  \
# 0         1.  ...      105,00 m²          2004.0                 NaN
# 1  Pritličje  ...       29,30 m²          1908.0              2020.0
# 2         1.  ...       11,00 m²          1961.0                 NaN
# 3         1.  ...       70,00 m²          2020.0                 NaN
# 4         7.  ...            NaN          1988.0                 NaN
#
#   Opremljenost in stanje                Energetski razred  \
# 0                    NaN                              NaN
# 1   Popolnoma opremljeno  EI ni potrebna (334. člen EZ-1)
# 2                    NaN            E (105 - 150 kWh/m2a)
# 3           Neopremljeno             A2 (10 - 15 kWh/m2a)
# 4                    NaN                              NaN
#
#                        Možnost menjave Število parkirnih mest  \
# 0                                  NaN                    NaN
# 1  Možna menjava za drugo nepremičnino                    NaN
# 2                                  NaN                    NaN
# 3                                  NaN                     7+
# 4                                  NaN                    NaN
#
#   Balkon / terasa / atrij Zunanje površine in oprema Interna številka oglasa
# 0                     NaN                        NaN                     NaN
# 1                     NaN                        NaN                     NaN
# 2                     NaN                        NaN                     NaN
# 3            Balkon, Loža                        NaN                     NaN
# 4            Zaprt balkon                        NaN                     NaN
#
# [5 rows x 23 columns]

# %%
data.columns
# Out:
# Index(['Šifra oglasa', 'Objavljen ', 'Do poteka še', 'Število prikazov oglasa',
#        'Cena', 'Vrsta cene', 'Posredovanje', 'Lokacija',
#        'Umeščenost stanovanja', 'Nadstropje',
#        'Skupno število nadstropij v stavbi', 'Vrsta stanovanja',
#        'Bivalna površina', 'Neto površina', 'Leto izgradnje*',
#        'Leto zadnje prenove', 'Opremljenost in stanje', 'Energetski razred',
#        'Možnost menjave', 'Število parkirnih mest', 'Balkon / terasa / atrij',
#        'Zunanje površine in oprema', 'Interna številka oglasa'],
#       dtype='object')

# %% [markdown]
# ## Preprocessing
# Manipulating entries to derive numerical features from raw screaped values.

# %%
    
    
    for i in df:

# %%
# taking a look at the unique values of for columns (all but the first 5)
for column in df.columns[5:]:
    print(df[column].unique())

# %%
# Objavljen > objavljen posted_date + posted_time...
def prepareFeatures (df): 
    a = {}
    main_df = pd.DataFrame()
    
    for i in tqdm(range(0,len(df))):
        a['AD_ID'] = df.iloc[i]['Šifra oglasa']

        a['posted_date'] = df.iloc[i]['Objavljen '].split('dne')[0]
        a['posted_time'] = df.iloc[i]['Objavljen '].split('dne')[1]

        a['shown'] = df.iloc[i]['Število prikazov oglasa'].split('-')[0]

        a['price'] =  np.nan if df.iloc[i]['Cena'] == '\npodogovoru' else df.iloc[i]['Cena'].split('\n')[2].split('\xa0')[0].replace('.','')
        a['currency'] = np.nan if df.iloc[i]['Cena'] == '\npodogovoru' else df.iloc[i]['Cena'].split('\n')[2].split('\xa0')[1]

        a['ptype'] = 'cumulative' if df.iloc[i]['Vrsta cene'] == 'Skupna cena' else 'perM2'

        a['l_region'] = df.iloc[i]['Lokacija'].split(',')[0]
        a['l_2'] = df.iloc[i]['Lokacija'].split(',')[1].replace(' ', '')
        a['l_3'] = df.iloc[i]['Lokacija'].split(',')[2].replace(' ', '')

        a['sits_in'] = df.iloc[i]['Umeščenost stanovanja']

        a['lvl'] = df.iloc[i]['Nadstropje'] if str(df.iloc[i]['Nadstropje']) == 'nan' else     'P' if df.iloc[i]['Nadstropje'] == 'Pritličje' else 'K' if df.iloc[i]['Nadstropje'] == 'Klet' else     'M' if df.iloc[i]['Nadstropje'] == 'Mansarda' else    'VP' if df.iloc[i]['Nadstropje'] == 'Visoko pritličje' else df.iloc[i]['Nadstropje'].split('.')[0] 

        a['t_lvl'] = df.iloc[i]['Skupno število nadstropij v stavbi'] if str(df.iloc[i]['Skupno število nadstropij v stavbi']) == 'nan' else int(df.iloc[i]['Skupno število nadstropij v stavbi'])

        a['flat_type'] = df.iloc[i]['Vrsta stanovanja']

        a['sizeM2'] = df.iloc[i]['Bivalna površina'] if str(df.iloc[i]['Bivalna površina']) == 'nan' else df.iloc[i]['Bivalna površina'].split(',')[0]

        a['net_sizeM2'] = df.iloc[i]['Neto površina'] if str(df.iloc[i]['Neto površina']) == 'nan' else df.iloc[i]['Neto površina'].split(',')[0]

        a['year_built'] = df.iloc[i]['Leto izgradnje*'] if str(df.iloc[i]['Leto izgradnje*']) == 'nan' else df.iloc[i]['Leto izgradnje*']

        a['year_ren'] = df.iloc[i]['Leto zadnje prenove'] if str(df.iloc[i]['Leto zadnje prenove']) == 'nan' else df.iloc[i]['Leto zadnje prenove']

        a['condition'] = df.iloc[i]['Opremljenost in stanje']

        a['en_eff'] = df.iloc[i]['Energetski razred'] if str(df.iloc[i]['Energetski razred']) == 'nan'else df.iloc[i]['Energetski razred'].split(' ')[0] + df.iloc[i]['Energetski razred'].split(' ')[-1] if str(df.iloc[i]['Energetski razred'].split(' ')[-1]) == 'HR' else  df.iloc[i]['Energetski razred'].split(' ')[0]

        a['switch'] = df.iloc[i]['Možnost menjave'] if str(df.iloc[i]['Možnost menjave']) == 'nan' else 'yes' if df.iloc[i]['Možnost menjave'] == 'Možna menjava za drugo nepremičnino' else 'no' if df.iloc[i]['Možnost menjave'] == 'Menjava za drugo nepremičnino ni možna'  else 'nan'

        a['park_spots'] =  '0' if df.iloc[i]['Število parkirnih mest']  == 'brez pripadajočega parkirišča' else df.iloc[i]['Število parkirnih mest'].split('+')[0] if str(df.iloc[i]['Število parkirnih mest']) != 'nan' else 'nan'
       
        a['balcony'] = 'yes' if str(df.iloc[i]['Balkon / terasa / atrij']) != 'nan' else 'no'
        a['garden'] = 'yes' if str(df.iloc[i]['Zunanje površine in oprema']) != 'nan' else 'no'
        
        a_df = pd.DataFrame.from_dict([a])
        main_df = pd.concat([main_df,a_df],axis=0, ignore_index=True)
    return main_df
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 109.94it/s]
#       AD_ID posted_date posted_time shown      price currency       ptype  \
# 0   6523968  14.03.2021       18:49    57     192000        €  cumulative
# 1   6523894  14.03.2021       18:39    29     134500        €  cumulative
# 2   6523589  14.03.2021       18:07    33      29500        €  cumulative
# 3   6523431  14.03.2021       17:47    34     120000        €  cumulative
# 4   6523190  14.03.2021       17:16    23     180000        €  cumulative
# 5   4980667  14.03.2021       15:59  1754      69900        €  cumulative
# 6   6522471  14.03.2021       15:55    37      75000        €  cumulative
# 7   6522357  14.03.2021       15:38    66      50000        €  cumulative
# 8   6522107  14.03.2021       14:59    64        NaN      NaN  cumulative
# 9   1459215  14.03.2021       13:51  9507     165000        €  cumulative
# 10  6521099  14.03.2021       12:51   479     130000        €  cumulative
# 11  6520120  14.03.2021       11:13   153     116900        €  cumulative
# 12  6520057  14.03.2021       11:07    96      69000        €  cumulative
# 13  6520021  14.03.2021       11:03    54      40800        €  cumulative
# 14  6519881  14.03.2021       10:51    49          0        €  cumulative
# 15  6519704  14.03.2021       10:35   117      55000        €  cumulative
# 16  5569668  14.03.2021       09:22   604      48000        €  cumulative
# 17  3174984  14.03.2021       08:50  2045      99900        €  cumulative
# 18  1448717  14.03.2021       08:23  1295     159900        €  cumulative
# 19  1452932  14.03.2021       08:20  3332      98900        €  cumulative
# 20  6515431  14.03.2021       00:15    55      90000        €  cumulative
# 21  6515122  14.03.2021       00:12   119     120000        €  cumulative
# 22  6325861  13.03.2021       22:50  1320      98000        €  cumulative
# 23  6514832  13.03.2021       21:27    24     210000        €  cumulative
# 24  6514758  13.03.2021       20:59   105      49104        €  cumulative
# 25  6078810  13.03.2021       18:30  1389      65000        €  cumulative
# 26  3211042  13.03.2021       15:53   462     199000        €  cumulative
# 27  5298888  13.03.2021       13:33  2196  223932,98        €  cumulative
# 28  4383951  13.03.2021       13:33   862  174074,89        €  cumulative
# 29  4359089  13.03.2021       13:33  5461  129226,43        €  cumulative
# 30  2218823  13.03.2021       13:33  6069  156119,63        €  cumulative
# 31  6281325  13.03.2021       13:01   165     140000        €  cumulative
# 32  6512420  13.03.2021       12:54   553      67500        €  cumulative
# 33  6512199  13.03.2021       12:12   105     220000        €  cumulative
# 34  6507401  13.03.2021       00:16   131     105000        €  cumulative
# 35  6507236  13.03.2021       00:15   124     160000        €  cumulative
# 36  6507148  13.03.2021       00:13   163      40000        €  cumulative
# 37  4486962  12.03.2021       23:37  1599     135000        €  cumulative
# 38  1452622  12.03.2021       21:06   707     389900        €  cumulative
# 39  4465526  12.03.2021       20:38   928      40000        €  cumulative
# 40  2611516  12.03.2021       20:37  1379      14000        €  cumulative
# 41  6506244  12.03.2021       18:30    44        NaN      NaN  cumulative
# 42  4533343  12.03.2021       18:05  2460      84000        €  cumulative
# 43  1470990  12.03.2021       17:21  3375      60000        €  cumulative
# 44  2777351  12.03.2021       16:16  5965     120000        €  cumulative
# 45  6505505  12.03.2021       15:51   371     149000        €  cumulative
# 46  6504897  12.03.2021       13:28   136     168000        €  cumulative
# 47  6504843  12.03.2021       13:17    95     130000        €  cumulative
# 48  1447252  12.03.2021       13:05  1349     140000        €  cumulative
# 49  1450839  12.03.2021       12:59  2718      45000        €  cumulative
#
#                      l_region                l_2                l_3  ...  \
# 0                   Savinjska              Celje      SlavkoŠlander  ...
# 1           Osrednjeslovenska    LjubljanaCenter             Center  ...
# 2                   Gorenjska              Tržič              Tržič  ...
# 3                   Savinjska   SlovenskeKonjice   SlovenskeKonjice  ...
# 4           Osrednjeslovenska  LjubljanaBežigrad           Bežigrad  ...
# 5                   Podravska          Kidričevo          Kidričevo  ...
# 6           Osrednjeslovenska            Domžale            Domžale  ...
# 7                     Koroška           Podvelka           Podvelka  ...
# 8           Osrednjeslovenska            Vrhnika            Vrhnika  ...
# 9           Osrednjeslovenska  LjubljanaBežigrad            Stožice  ...
# 10                  Savinjska            Velenje            Velenje  ...
# 11                  Podravska            Maribor            NovaVas  ...
# 12                  Podravska            Dornava            Dornava  ...
# 13                  Podravska               Ptuj               Ptuj  ...
# 14                   Pomurska       MurskaSobota       MurskaSobota  ...
# 15                  Podravska             Starše           Prepolje  ...
# 16      Jugovzhodna Slovenija            Kočevje            Kočevje  ...
# 17                  Podravska            Maribor             Center  ...
# 18                  Podravska            Maribor          Magdalena  ...
# 19                  Podravska            Maribor             Center  ...
# 20                  Savinjska              Celje              Celje  ...
# 21                  Podravska            Maribor           Studenci  ...
# 22                  Podravska               Ruše    BistricaobDravi  ...
# 23  Izven Slovenije - Hrvaška           Zadarska                Vir  ...
# 24                   Pomurska    MoravskeToplice    MoravskeToplice  ...
# 25                  Podravska            Maribor           Studenci  ...
# 26                  Savinjska              Celje            Novavas  ...
# 27                  Podravska            Maribor           Studenci  ...
# 28                  Podravska            Maribor           Studenci  ...
# 29                  Podravska            Maribor           Studenci  ...
# 30                  Podravska            Maribor           Studenci  ...
# 31       Primorsko-notranjska           Postojna           Postojna  ...
# 32                  Podravska            Maribor     Borštnikovaul.  ...
# 33          Osrednjeslovenska          Ljubljana           Topniška  ...
# 34                  Podravska  SlovenskaBistrica  SlovenskaBistrica  ...
# 35          Osrednjeslovenska     LjubljanaŠiška              Šiška  ...
# 36                    Koroška      RadljeobDravi      RadljeobDravi  ...
# 37                  Podravska            Maribor          Magdalena  ...
# 38          Osrednjeslovenska    LjubljanaCenter             Trnovo  ...
# 39                    Koroška           Podvelka           Podvelka  ...
# 40                    Koroška           Podvelka           Podvelka  ...
# 41                    Goriška         NovaGorica         NovaGorica  ...
# 42                    Koroška    RavnenaKoroškem    RavnenaKoroškem  ...
# 43                   Pomurska            Lendava            Lendava  ...
# 44                  Savinjska              Celje              Celje  ...
# 45                  Podravska            Maribor          Magdalena  ...
# 46          Osrednjeslovenska     LjubljanaŠiška              Šiška  ...
# 47          Osrednjeslovenska      IvančnaGorica      IvančnaGorica  ...
# 48                  Savinjska            Prebold            Prebold  ...
# 49                  Savinjska            Prebold            Prebold  ...
#
#    sizeM2 net_sizeM2  year_built year_ren             condition en_eff  \
# 0      86        105      2004.0      NaN                   NaN    NaN
# 1      28         29      1908.0   2020.0  Popolnoma opremljeno     EI
# 2      11         11      1961.0      NaN                   NaN      E
# 3     NaN         70      2020.0      NaN          Neopremljeno     A2
# 4      53        NaN      1988.0      NaN                   NaN    NaN
# 5      59        NaN         NaN   2013.0  Popolnoma opremljeno    NaN
# 6      27         30      1980.0      NaN                   NaN    NaN
# 7      52        NaN      1980.0   2019.0  Popolnoma opremljeno     A1
# 8      60         85      1952.0   2010.0      Delno opremljeno     EI
# 9      38         40      1976.0   2018.0  Popolnoma opremljeno    NaN
# 10    NaN        NaN      1973.0      NaN                   NaN      D
# 11     78        NaN      1979.0      NaN  Popolnoma opremljeno    NaN
# 12    NaN         53      2009.0   2016.0                   NaN    NaN
# 13     24        NaN      1980.0   2010.0      Delno opremljeno    NaN
# 14     14        NaN      1970.0      NaN                   NaN    NaN
# 15     80         80      1960.0   2010.0                   NaN    NaN
# 16     43         43      1963.0   2010.0      Delno opremljeno     EI
# 17    200        NaN      1945.0   2018.0                   NaN    NaN
# 18    100        NaN      1950.0   2013.0                   NaN     EI
# 19    194        NaN      1919.0      NaN                   NaN     EI
# 20     96         96      1700.0   2020.0                   NaN    NaN
# 21     62         62      2008.0      NaN  Popolnoma opremljeno    NaN
# 22     70         75      1976.0   2014.0  Popolnoma opremljeno     EI
# 23     70        110      2020.0      NaN          Neopremljeno     A1
# 24     26         30      1995.0   2015.0  Popolnoma opremljeno      C
# 25     49        NaN      1994.0      NaN      Delno opremljeno      F
# 26    118         85      2009.0      NaN  Popolnoma opremljeno    NaN
# 27     90         98      2020.0      NaN      Delno opremljeno     B2
# 28     66         75      2021.0      NaN      Delno opremljeno     B1
# 29     43         77      2021.0      NaN          Neopremljeno     B2
# 30     65        101      2020.0      NaN          Neopremljeno     B2
# 31    NaN        115      1959.0      NaN       Potrebno obnove    DHR
# 32     44         41      1978.0   2016.0                   NaN    NaN
# 33     75        NaN      1952.0   2001.0                   NaN      E
# 34     45         53      2006.0   2018.0  Popolnoma opremljeno      C
# 35     43         46      1973.0   2020.0  Popolnoma opremljeno     EI
# 36    NaN        NaN      1900.0      NaN                   NaN    NaN
# 37    NaN         82      1945.0      NaN  Popolnoma opremljeno    NaN
# 38     77        NaN      1981.0   2013.0                   NaN    NaN
# 39     61         61      1800.0   1950.0       Potrebno obnove    NaN
# 40     24        NaN         NaN   1950.0                   NaN    NaN
# 41     66        NaN      1984.0   2015.0                   NaN     EI
# 42     63         68      1974.0   2017.0      Delno opremljeno    NaN
# 43     75        NaN         NaN   2014.0                   NaN     EI
# 44     89        122      1983.0   2009.0                   NaN    NaN
# 45     79         83      1971.0   2011.0                   NaN    NaN
# 46     56        NaN      1972.0      NaN                   NaN      C
# 47     61         66      2005.0      NaN                   NaN    NaN
# 48    130        NaN      1900.0   2017.0                   NaN     EI
# 49     31         31      1900.0   2017.0                   NaN     EI
#
#     switch  park_spots balcony garden
# 0      NaN         nan      no     no
# 1      yes         nan      no     no
# 2      NaN         nan      no     no
# 3      NaN           7     yes     no
# 4      NaN         nan     yes     no
# 5      NaN           2     yes     no
# 6      NaN         nan      no     no
# 7      NaN           2     yes    yes
# 8      yes         nan     yes     no
# 9       no           1     yes     no
# 10     NaN         nan     yes     no
# 11      no           1     yes    yes
# 12     NaN           1      no     no
# 13     NaN         nan      no     no
# 14     NaN         nan      no     no
# 15     NaN         nan      no    yes
# 16     yes           1      no    yes
# 17     NaN         nan      no     no
# 18     NaN         nan      no     no
# 19     NaN         nan      no     no
# 20     NaN         nan      no     no
# 21     NaN         nan      no     no
# 22     NaN           1     yes     no
# 23     NaN         nan     yes    yes
# 24     NaN         nan     yes    yes
# 25     NaN         nan      no    yes
# 26      no         nan     yes     no
# 27     NaN         nan     yes     no
# 28     NaN         nan     yes     no
# 29     NaN         nan     yes     no
# 30     NaN         nan     yes    yes
# 31     NaN         nan     yes     no
# 32     NaN         nan      no    yes
# 33     NaN         nan     yes     no
# 34      no           2      no     no
# 35      no           0     yes     no
# 36     NaN         nan      no    yes
# 37     NaN         nan      no    yes
# 38     NaN         nan     yes     no
# 39     NaN         nan      no     no
# 40     NaN         nan      no     no
# 41     NaN         nan     yes     no
# 42     yes         nan      no     no
# 43     NaN         nan     yes     no
# 44     NaN         nan     yes     no
# 45     NaN         nan     yes     no
# 46     NaN         nan     yes     no
# 47     NaN         nan     yes     no
# 48     NaN         nan     yes     no
# 49      no         nan     yes     no
#
# [50 rows x 24 columns]

# %%
df.iloc[0]['Skupno število nadstropij v stavbi']
# Out:
# 2.0

# %%
df.iloc[1]['Lokacija'].split(',')[1].replace(' ', '')
# Out:
# 'LjubljanaCenter'

# %%
# taking a look at the unique values of for columns (all but the first 5)
for column in df.columns[5:]:
    print(column)
    print(df[column].unique())
# Out:
# Vrsta cene
# ['Skupna cena' 'Cena na m²']
# Posredovanje
# ['Prodam']
# Lokacija
# ['Savinjska, Celje, Slavko Šlander'
#  'Osrednjeslovenska, Ljubljana Center, Center' 'Gorenjska, Tržič, Tržič'
#  'Savinjska, Slovenske Konjice, Slovenske Konjice'
#  'Osrednjeslovenska, Ljubljana Bežigrad, Bežigrad'
#  'Podravska, Kidričevo, Kidričevo' 'Osrednjeslovenska, Domžale, Domžale'
#  'Koroška, Podvelka, Podvelka' 'Osrednjeslovenska, Vrhnika, Vrhnika'
#  'Osrednjeslovenska, Ljubljana Bežigrad, Stožice'
#  'Savinjska, Velenje, Velenje' 'Podravska, Maribor, Nova Vas'
#  'Podravska, Dornava, Dornava' 'Podravska, Ptuj, Ptuj'
#  'Pomurska, Murska Sobota, Murska Sobota' 'Podravska, Starše, Prepolje'
#  'Jugovzhodna Slovenija, Kočevje, Kočevje' 'Podravska, Maribor, Center'
#  'Podravska, Maribor, Magdalena' 'Savinjska, Celje, Celje'
#  'Podravska, Maribor, Studenci' 'Podravska, Ruše, Bistrica ob Dravi'
#  'Izven Slovenije - Hrvaška, Zadarska, Vir'
#  'Pomurska, Moravske Toplice, Moravske Toplice'
#  'Savinjska, Celje, Nova vas' 'Primorsko-notranjska, Postojna, Postojna'
#  'Podravska, Maribor, Borštnikova ul.'
#  'Osrednjeslovenska, Ljubljana, Topniška'
#  'Podravska, Slovenska Bistrica, Slovenska Bistrica'
#  'Osrednjeslovenska, Ljubljana Šiška, Šiška'
#  'Koroška, Radlje ob Dravi, Radlje ob Dravi'
#  'Osrednjeslovenska, Ljubljana Center, Trnovo'
#  'Goriška, Nova Gorica, Nova Gorica'
#  'Koroška, Ravne na Koroškem, Ravne na Koroškem'
#  'Pomurska, Lendava, Lendava'
#  'Osrednjeslovenska, Ivančna Gorica, Ivančna Gorica'
#  'Savinjska, Prebold, Prebold' 'Savinjska, Celje, Savinja'
#  'Pomurska, Šalovci, Šalovci' 'Pomurska, Apače, Apače'
#  'Podravska, Maribor, Pobrežje' 'Savinjska, Braslovče, Gomilsko'
#  'Podravska, Maribor, Betnava' 'Obalno-kraška, Piran, Piran'
#  'Izven Slovenije - Hrvaška, Istrska, Pula' 'Savinjska, Celje, Lava'
#  'Podravska, Maribor okolica, Trčova'
#  'Izven Slovenije - Hrvaška, Istrska, Brtonigla'
#  'Podravska, Lenart v Slovenskih goricah, Lenart v Slovenskih goricah'
#  'Podravska, Maribor, Melje' 'Savinjska, Dobrna, Vinska Gorica'
#  'Podravska, Oplotnica, Oplotnica' 'Podravska, Maribor, Radvanje'
#  'Osrednjeslovenska, Ljubljana Vič Rudnik, Rudnik'
#  'Osrednjeslovenska, Litija, Litija' 'Zasavska, Trbovlje, Trbovlje']
# Umeščenost stanovanja
# ['V večstanovanjski stavbi' nan 'V hiši']
# Nadstropje
# ['1.' 'Pritličje' '7.' nan '2.' '3.' '4.' 'Mansarda' '5.' 'Klet'
#  'Visoko pritličje' '8.' '6.']
# Skupno število nadstropij v stavbi
# [ 2.  4.  5.  7. nan  3. 10.  8.  1. 14.]
# Vrsta stanovanja
# ['3-sobno' 'Garsonjera' '2-sobno' '1,5-sobno' nan '2,5-sobno' 'Apartma'
#  '4,5-sobno' '3,5-sobno' '4-sobno' '1-sobno' '6 in večsobno' '5-sobno']
# Bivalna površina
# ['86,00 m²' '28,60 m²' '11,00 m²' nan '53,50 m²' '59,00 m²' '27,00 m²'
#  '52,00 m²' '60,20 m²' '38,00 m²' '78,00 m²' '24,00 m²' '14,00 m²'
#  '80,00 m²' '43,00 m²' '200,00 m²' '100,00 m²' '194,00 m²' '96,00 m²'
#  '62,00 m²' '70,00 m²' '26,09 m²' '49,00 m²' '118,00 m²' '90,30 m²'
#  '66,50 m²' '43,50 m²' '65,00 m²' '44,90 m²' '75,00 m²' '45,40 m²'
#  '43,12 m²' '77,20 m²' '61,90 m²' '24,50 m²' '66,00 m²' '63,00 m²'
#  '89,00 m²' '79,40 m²' '56,20 m²' '61,50 m²' '130,00 m²' '31,00 m²'
#  '73,00 m²' '97,40 m²' '189,20 m²' '39,00 m²' '58,00 m²' '67,91 m²'
#  '151,16 m²' '95,79 m²' '79,89 m²' '72,28 m²' '66,30 m²' '58,99 m²'
#  '72,77 m²' '77,63 m²' '72,37 m²' '57,22 m²' '68,19 m²' '66,16 m²'
#  '106,20 m²' '65,67 m²' '37,00 m²' '384,00 m²' '57,00 m²' '57,93 m²'
#  '68,26 m²' '68,31 m²' '22,10 m²' '72,00 m²' '97,80 m²' '46,30 m²'
#  '150,00 m²' '62,60 m²' '60,00 m²' '77,19 m²' '94,00 m²' '65,30 m²'
#  '267,00 m²' '133,00 m²' '106,00 m²' '125,00 m²' '71,00 m²' '45,00 m²'
#  '138,90 m²']
# Neto površina
# ['105,00 m²' '29,30 m²' '11,00 m²' '70,00 m²' nan '30,00 m²' '85,30 m²'
#  '40,00 m²' '53,00 m²' '80,00 m²' '43,00 m²' '96,00 m²' '62,00 m²'
#  '75,00 m²' '110,00 m²' '30,69 m²' '85,00 m²' '98,40 m²' '75,20 m²'
#  '77,30 m²' '101,70 m²' '115,00 m²' '41,20 m²' '53,20 m²' '46,12 m²'
#  '82,30 m²' '61,90 m²' '68,00 m²' '122,00 m²' '83,40 m²' '66,00 m²'
#  '31,00 m²' '83,60 m²' '44,00 m²' '107,90 m²' '58,00 m²' '37,00 m²'
#  '384,00 m²' '81,60 m²' '65,00 m²' '22,10 m²' '150,00 m²' '60,00 m²'
#  '115,30 m²' '94,00 m²' '77,80 m²' '267,00 m²' '133,00 m²' '106,00 m²'
#  '73,00 m²' '125,00 m²' '138,90 m²']
# Leto izgradnje*
# [2004. 1908. 1961. 2020. 1988.   nan 1980. 1952. 1976. 1973. 1979. 2009.
#  1970. 1960. 1963. 1945. 1950. 1919. 1700. 2008. 1995. 1994. 2021. 1959.
#  1978. 2006. 1900. 1981. 1800. 1984. 1974. 1983. 1971. 1972. 2005. 2019.
#  1958. 1982. 1860. 1996. 2010. 1975. 1888. 1966. 1977. 1965. 2000. 1938.
#  1830. 1880. 1897. 1990. 1924. 1999.]
# Leto zadnje prenove
# [  nan 2020. 2013. 2019. 2010. 2018. 2016. 2014. 2015. 2001. 1950. 2017.
#  2009. 2011. 2008. 2021. 1999.]
# Opremljenost in stanje
# [nan 'Popolnoma opremljeno' 'Neopremljeno' 'Delno opremljeno'
#  'Potrebno obnove']
# Energetski razred
# [nan 'EI ni potrebna (334. člen EZ-1)' 'E (105 - 150 kWh/m2a)'
#  'A2 (10 - 15 kWh/m2a)' 'A1 (0 - 10 kWh/m2a)' 'EI v izdelavi'
#  'D (60 - 105 kWh/m2a)' 'C (35 - 60 kWh/m2a)' 'F (150 - 210 kWh/m2a)'
#  'B2 (25 - 35 kWh/m2a)' 'B1 (15 - 25 kWh/m2a)'
#  'D (101 do 150 kWh/m2a) - HR' 'A (16 do 25 kWh/m2a) - HR'
#  'F (201 do 250 kWh/m2a) - HR']
# Možnost menjave
# [nan 'Možna menjava za drugo nepremičnino'
#  'Menjava za drugo nepremičnino ni možna']
# Število parkirnih mest
# [nan '7+' '2' '1' 'brez pripadajočega parkirišča']
# Balkon / terasa / atrij
# [nan 'Balkon, Loža' 'Zaprt balkon' 'Balkon' 'Balkon, Terasa' 'Loža'
#  'Terasa, Loža, Atrij' 'Terasa' 'Atrij' 'Balkon, Atrij']
# Zunanje površine in oprema
# [nan 'Vrt/dvorišče, Lopa za shranjevanje, Vrtna uta' 'Vrt/dvorišče'
#  'Lopa za shranjevanje'
#  'Vrt/dvorišče, Lopa za shranjevanje, Vrtna uta, Žar, Bazen']
# Interna številka oglasa
# [nan 'PS00491JP' '943' '5214' '100108-484' '101179-306' '490271003-298'
#  'GALEA 2021/391' '1052' 'GALEA 2021/395' '1053' 'P2' '1054'
#  'GALEA 2021/409' 'GALEA 2021/396' 'GALEA 2021/397' 'GALEA 2021/399'
#  'GALEA 2021/401' 'GALEA 2021/402' 'GALEA 2021/400' 'GALEA 2021/407'
#  'GALEA 2021/404' 'GALEA 2021/406' 'GALEA 2021/410' 'GALEA 2021/412'
#  'GALEA 2021/411' 'GALEA 2021/414' 'PS38621907BM' 'PS4646642PB'
#  '107209-56' 'PS4646054MR' 'GALEA 2021/405' 'GALEA 2021/403'
#  'GALEA 2021/398' 'J3' 'PS4645466MR - 5' 'PS4646640MM' '101108-483'
#  '107209-55' 'PS38621906PV' 'PS38621905PV' 'PS00714PD' 'KODA: P1283CE']

# %%
df['Objavljen '][4:5]
# Out:
# 4    14.03.2021dne17:16
# Name: Objavljen , dtype: object

# %%
############### only as a tool
def scrape_content(page):
    a = {}
    
    # adding details about the ad (first published, times viewed...)
    ad_info = page.find('ul', class_ = 'meta-items')

    for item in ad_info.find_all('li'):   
        f_names = item.find('span', class_='label').text
        f_atr = item.find(class_='value').text

        a[f_names.replace(':', '')] = f_atr.replace(' ', '')

    # adding property price
    div_price = page.find('ul', class_ = 'price-items cf')
    f_names= div_price.find(class_='label').text
    f_price_raw =  div_price.find(class_='price price--hrk').text.replace(' ', '')
    
    f_atr = f_price_raw
    #f_price_raw if str(f_price_raw) == 'podogovoru' else f_price_raw.split('\n')[2].replace(u'\xa0', u' ')

    a[f_names.replace(':', '')] = f_atr

    # adding info about the property
    table_info = page.find('tbody')

    for item in table_info.find_all('tr'):
        f_names = item.find('th')
        f_atr = item.find('td')

        a[f_names.text.replace(':', '')] = f_atr.text
        
    # make dict a into a df. 
    a_df = pd.DataFrame.from_dict([a])
        
    return a_df
