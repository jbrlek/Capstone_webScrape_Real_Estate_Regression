# %%
import pandas as pd
import numpy as np
import time
import datetime
from tqdm import tqdm
import random

import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %%
data = pd.read_csv('bolha_flats_all_info1-49_14-03-2021_20-55-58.csv')

# %%
data= data.drop('Unnamed: 0', axis = 1)

# %%
data.head()
# Out:
#    Šifra oglasa          Objavljen           Do poteka še  \
# 0       6523968  14.03.2021dne18:49  \n29dni,22h,33min.\n
# 1       6523894  14.03.2021dne18:39  \n29dni,22h,24min.\n
# 2       6523589  14.03.2021dne18:07  \n29dni,21h,52min.\n
# 3       6523431  14.03.2021dne17:47  \n29dni,21h,32min.\n
# 4       6523190  14.03.2021dne17:16   \n29dni,21h,0min.\n
#
#   Število prikazov oglasa             Cena   Vrsta cene Posredovanje  \
# 0                 57-krat  \n\n192.000 €\n  Skupna cena       Prodam
# 1                 29-krat  \n\n134.500 €\n  Skupna cena       Prodam
# 2                 33-krat   \n\n29.500 €\n  Skupna cena       Prodam
# 3                 34-krat  \n\n120.000 €\n  Skupna cena       Prodam
# 4                 23-krat  \n\n180.000 €\n  Skupna cena       Prodam
#
#                                           Lokacija     Umeščenost stanovanja  \
# 0                 Savinjska, Celje, Slavko Šlander  V večstanovanjski stavbi
# 1      Osrednjeslovenska, Ljubljana Center, Center  V večstanovanjski stavbi
# 2                          Gorenjska, Tržič, Tržič  V večstanovanjski stavbi
# 3  Savinjska, Slovenske Konjice, Slovenske Konjice  V večstanovanjski stavbi
# 4  Osrednjeslovenska, Ljubljana Bežigrad, Bežigrad  V večstanovanjski stavbi
#
#   Nadstropje  ...  Neto površina Leto izgradnje* Leto zadnje prenove  \
# 0         1.  ...      105,00 m²          2004.0                 NaN
# 1  Pritličje  ...       29,30 m²          1908.0              2020.0
# 2         1.  ...       11,00 m²          1961.0                 NaN
# 3         1.  ...       70,00 m²          2020.0                 NaN
# 4         7.  ...            NaN          1988.0                 NaN
#
#   Opremljenost in stanje                Energetski razred  \
# 0                    NaN                              NaN
# 1   Popolnoma opremljeno  EI ni potrebna (334. člen EZ-1)
# 2                    NaN            E (105 - 150 kWh/m2a)
# 3           Neopremljeno             A2 (10 - 15 kWh/m2a)
# 4                    NaN                              NaN
#
#                        Možnost menjave Število parkirnih mest  \
# 0                                  NaN                    NaN
# 1  Možna menjava za drugo nepremičnino                    NaN
# 2                                  NaN                    NaN
# 3                                  NaN                     7+
# 4                                  NaN                    NaN
#
#   Balkon / terasa / atrij Zunanje površine in oprema Interna številka oglasa
# 0                     NaN                        NaN                     NaN
# 1                     NaN                        NaN                     NaN
# 2                     NaN                        NaN                     NaN
# 3            Balkon, Loža                        NaN                     NaN
# 4            Zaprt balkon                        NaN                     NaN
#
# [5 rows x 23 columns]

# %%
data.columns
# Out:
# Index(['Šifra oglasa', 'Objavljen ', 'Do poteka še', 'Število prikazov oglasa',
#        'Cena', 'Vrsta cene', 'Posredovanje', 'Lokacija',
#        'Umeščenost stanovanja', 'Nadstropje',
#        'Skupno število nadstropij v stavbi', 'Vrsta stanovanja',
#        'Bivalna površina', 'Neto površina', 'Leto izgradnje*',
#        'Leto zadnje prenove', 'Opremljenost in stanje', 'Energetski razred',
#        'Možnost menjave', 'Število parkirnih mest', 'Balkon / terasa / atrij',
#        'Zunanje površine in oprema', 'Interna številka oglasa'],
#       dtype='object')

# %% [markdown]
# ## Preprocessing
# Manipulating entries to derive numerical features from raw screaped values.

# %%
# taking a look at the unique values of for columns (all but the first 5)
for column in data.columns[5:]:
    print(data[column].unique())
# Out:
# ['\n\n192.000\xa0€\n' '\n\n134.500\xa0€\n' '\n\n29.500\xa0€\n'
#  '\n\n120.000\xa0€\n' '\n\n180.000\xa0€\n' '\n\n69.900\xa0€\n'
#  '\n\n75.000\xa0€\n' '\n\n50.000\xa0€\n' '\npodogovoru'
#  '\n\n165.000\xa0€\n' '\n\n130.000\xa0€\n' '\n\n116.900\xa0€\n'
#  '\n\n69.000\xa0€\n' '\n\n40.800\xa0€\n' '\n\n0\xa0€\n'
#  '\n\n55.000\xa0€\n' '\n\n48.000\xa0€\n' '\n\n99.900\xa0€\n'
#  '\n\n159.900\xa0€\n' '\n\n98.900\xa0€\n' '\n\n90.000\xa0€\n'
#  '\n\n98.000\xa0€\n' '\n\n210.000\xa0€\n' '\n\n49.104\xa0€\n'
#  '\n\n65.000\xa0€\n' '\n\n199.000\xa0€\n' '\n\n223.932,98\xa0€\n'
#  '\n\n174.074,89\xa0€\n' '\n\n129.226,43\xa0€\n' '\n\n156.119,63\xa0€\n'
#  '\n\n140.000\xa0€\n' '\n\n67.500\xa0€\n' '\n\n220.000\xa0€\n'
#  '\n\n105.000\xa0€\n' '\n\n160.000\xa0€\n' '\n\n40.000\xa0€\n'
#  '\n\n135.000\xa0€\n' '\n\n389.900\xa0€\n' '\n\n14.000\xa0€\n'
#  '\n\n84.000\xa0€\n' '\n\n60.000\xa0€\n' '\n\n149.000\xa0€\n'
#  '\n\n168.000\xa0€\n' '\n\n45.000\xa0€\n' '\n\n145.000\xa0€\n'
#  '\n\n230.000\xa0€\n' '\n\n187.800\xa0€\n' '\n\n1.690\xa0€\n'
#  '\n\n110.000\xa0€\n' '\n\n30.000\xa0€\n' '\n\n104.585\xa0€\n'
#  '\n\n123.533\xa0€\n' '\n\n92.177\xa0€\n' '\n\n121.375\xa0€\n'
#  '\n\n195.000\xa0€\n' '\n\n111.158\xa0€\n' '\n\n101.520\xa0€\n'
#  '\n\n89.017\xa0€\n' '\n\n115.517\xa0€\n' '\n\n119.581\xa0€\n'
#  '\n\n111.229\xa0€\n' '\n\n90.633\xa0€\n' '\n\n108.478\xa0€\n'
#  '\n\n104.906\xa0€\n' '\n\n139.999\xa0€\n' '\n\n101.028\xa0€\n'
#  '\n\n175.000\xa0€\n' '\n\n487.000\xa0€\n' '\n\n1.300\xa0€\n'
#  '\n\n79.900\xa0€\n' '\n\n119.000\xa0€\n' '\n\n88.104\xa0€\n'
#  '\n\n104.918\xa0€\n' '\n\n115.557\xa0€\n' '\n\n43.000\xa0€\n'
#  '\n\n99.000\xa0€\n' '\n\n299.000\xa0€\n' '\n\n71.175\xa0€\n'
#  '\n\n180\xa0€\n' '\n\n75.595,84\xa0€\n' '\n\n420.000\xa0€\n'
#  '\n\n295.000\xa0€\n' '\n\n365.000\xa0€\n' '\n\n74.270\xa0€\n'
#  '\n\n33.450\xa0€\n' '\n\n129.000\xa0€\n' '\n\n600.000\xa0€\n'
#  '\n\n115.000\xa0€\n' '\n\n99.990\xa0€\n' '\n\n900\xa0€\n'
#  '\n\n162.800\xa0€\n' '\n\n79.999\xa0€\n' '\n\n89.000\xa0€\n'
#  '\n\n338.000\xa0€\n' '\n\n228.000\xa0€\n' '\n\n182.630\xa0€\n'
#  '\n\n28.000\xa0€\n' '\n\n138.000\xa0€\n' '\n\n128.461\xa0€\n'
#  '\n\n97.105\xa0€\n' '\n\n120.485\xa0€\n' '\n\n126.303\xa0€\n'
#  '\n\n93.944\xa0€\n' '\n\n116.085\xa0€\n' '\n\n106.448\xa0€\n'
#  '\n\n109.512\xa0€\n' '\n\n124.508\xa0€\n' '\n\n93.031\xa0€\n'
#  '\n\n116.157\xa0€\n' '\n\n105.956\xa0€\n' '\n\n109.846\xa0€\n'
#  '\n\n95.560\xa0€\n' '\n\n120.444\xa0€\n' '\n\n109.833\xa0€\n'
#  '\n\n113.406\xa0€\n' '\n\n94.000\xa0€\n' '\n\n449.000\xa0€\n'
#  '\n\n488.000\xa0€\n' '\n\n498.000\xa0€\n' '\n\n528.000\xa0€\n'
#  '\n\n89.990\xa0€\n' '\n\n655.000\xa0€\n' '\n\n1.884.000\xa0€\n'
#  '\n\n489.000\xa0€\n' '\n\n29.000\xa0€\n' '\n\n78.000\xa0€\n'
#  '\n\n92.000\xa0€\n' '\n\n84.900\xa0€\n' '\n\n159.000\xa0€\n'
#  '\n\n139.900\xa0€\n' '\n\n103.000\xa0€\n' '\n\n70.500\xa0€\n'
#  '\n\n109.900\xa0€\n' '\n\n59.000\xa0€\n' '\n\n243.000\xa0€\n'
#  '\n\n128.000\xa0€\n' '\n\n238.000\xa0€\n' '\n\n193.000\xa0€\n'
#  '\n\n96.000\xa0€\n' '\n\n105.500\xa0€\n' '\n\n79.000\xa0€\n'
#  '\n\n59.900\xa0€\n' '\n\n51.000\xa0€\n' '\n\n57.990\xa0€\n'
#  '\n\n154.990\xa0€\n' '\n\n740.000\xa0€\n' '\n\n123.000\xa0€\n'
#  '\n\n58.000\xa0€\n' '\n\n67.000\xa0€\n' '\n\n239.000\xa0€\n'
#  '\n\n149.900\xa0€\n' '\n\n106.000\xa0€\n' '\n\n125.000\xa0€\n'
#  '\n\n83.000\xa0€\n' '\n\n189.000\xa0€\n' '\n\n459.000\xa0€\n'
#  '\n\n186.000\xa0€\n' '\n\n93.000\xa0€\n' '\n\n184.000\xa0€\n'
#  '\n\n69.500\xa0€\n' '\n\n155.000\xa0€\n' '\n\n88.000\xa0€\n'
#  '\n\n30.900\xa0€\n' '\n\n225.000\xa0€\n' '\n\n245.000\xa0€\n'
#  '\n\n128.900\xa0€\n' '\n\n490.500\xa0€\n' '\n\n54.000\xa0€\n'
#  '\n\n85.900\xa0€\n' '\n\n275.000\xa0€\n' '\n\n198.990\xa0€\n'
#  '\n\n259.000\xa0€\n' '\n\n117.000\xa0€\n' '\n\n156.000\xa0€\n'
#  '\n\n182.000\xa0€\n' '\n\n42.750\xa0€\n' '\n\n119.990\xa0€\n'
#  '\n\n199.900\xa0€\n' '\n\n229.000\xa0€\n' '\n\n300.000\xa0€\n'
#  '\n\n370.000\xa0€\n' '\n\n70.000\xa0€\n' '\n\n88.990\xa0€\n'
#  '\n\n200.000\xa0€\n' '\n\n103.990\xa0€\n' '\n\n1.290\xa0€\n'
#  '\n\n128.500\xa0€\n' '\n\n56.000\xa0€\n' '\n\n255.000\xa0€\n'
#  '\n\n280.000\xa0€\n' '\n\n255.500\xa0€\n' '\n\n90.100\xa0€\n'
#  '\n\n103.500\xa0€\n' '\n\n118.000\xa0€\n' '\n\n179.000\xa0€\n'
#  '\n\n190\xa0€\n' '\n\n305.000\xa0€\n' '\n\n219.000\xa0€\n'
#  '\n\n209.000\xa0€\n' '\n\n164.000\xa0€\n' '\n\n80.000\xa0€\n'
#  '\n\n66.000\xa0€\n' '\n\n224.000\xa0€\n' '\n\n170.000\xa0€\n'
#  '\n\n150.000\xa0€\n' '\n\n66.900\xa0€\n' '\n\n244.804\xa0€\n'
#  '\n\n149.343\xa0€\n' '\n\n122.229\xa0€\n' '\n\n188.000\xa0€\n'
#  '\n\n85.000\xa0€\n' '\n\n332.000\xa0€\n' '\n\n87.000\xa0€\n'
#  '\n\n136.875\xa0€\n' '\n\n164.250\xa0€\n' '\n\n229.950\xa0€\n'
#  '\n\n240.900\xa0€\n' '\n\n86.000\xa0€\n' '\n\n84.753\xa0€\n'
#  '\n\n750.000\xa0€\n' '\n\n520.000\xa0€\n' '\n\n139.500\xa0€\n'
#  '\n\n52.000\xa0€\n' '\n\n109.990\xa0€\n' '\n\n133.000\xa0€\n'
#  '\n\n127.000\xa0€\n' '\n\n800\xa0€\n' '\n\n100.000\xa0€\n'
#  '\n\n215.000\xa0€\n' '\n\n224.900\xa0€\n' '\n\n218.000\xa0€\n'
#  '\n\n76.000\xa0€\n' '\n\n77.000\xa0€\n' '\n\n95.202\xa0€\n'
#  '\n\n114.990\xa0€\n' '\n\n105\xa0€\n' '\n\n161.000\xa0€\n'
#  '\n\n260.000\xa0€\n' '\n\n290.000\xa0€\n' '\n\n236.900\xa0€\n'
#  '\n\n254.900\xa0€\n' '\n\n244.900\xa0€\n' '\n\n198.110\xa0€\n'
#  '\n\n205.904\xa0€\n' '\n\n82.000\xa0€\n' '\n\n37.000\xa0€\n'
#  '\n\n169.000\xa0€\n' '\n\n95.000\xa0€\n' '\n\n190.522\xa0€\n'
#  '\n\n195.479\xa0€\n' '\n\n185.871\xa0€\n' '\n\n249.900\xa0€\n'
#  '\n\n289.900\xa0€\n' '\n\n229.900\xa0€\n' '\n\n144.900\xa0€\n'
#  '\n\n194.948\xa0€\n' '\n\n198.471\xa0€\n' '\n\n39.000\xa0€\n'
#  '\n\n101.000\xa0€\n' '\n\n72.000\xa0€\n' '\n\n349.900\xa0€\n'
#  '\n\n500.000\xa0€\n' '\n\n980.000\xa0€\n' '\n\n149.200\xa0€\n'
#  '\n\n45.900\xa0€\n' '\n\n49.000\xa0€\n' '\n\n97.000\xa0€\n'
#  '\n\n124.400\xa0€\n' '\n\n138.800\xa0€\n' '\n\n123.300\xa0€\n'
#  '\n\n39.600\xa0€\n' '\n\n158.800\xa0€\n' '\n\n64.400\xa0€\n'
#  '\n\n107.500\xa0€\n' '\n\n32.000\xa0€\n' '\n\n39.900\xa0€\n'
#  '\n\n31.500\xa0€\n' '\n\n63.000\xa0€\n' '\n\n57.000\xa0€\n'
#  '\n\n283.800\xa0€\n' '\n\n320.000\xa0€\n' '\n\n234.000\xa0€\n'
#  '\n\n109.000\xa0€\n' '\n\n147.500\xa0€\n' '\n\n249.000\xa0€\n'
#  '\n\n690.000\xa0€\n' '\n\n682.000\xa0€\n' '\n\n686.000\xa0€\n'
#  '\n\n694.000\xa0€\n' '\n\n185.000\xa0€\n' '\n\n162.000\xa0€\n'
#  '\n\n329.000\xa0€\n' '\n\n671.000\xa0€\n' '\n\n559.000\xa0€\n'
#  '\n\n541.000\xa0€\n' '\n\n172.500\xa0€\n' '\n\n115.300\xa0€\n'
#  '\n\n109.500\xa0€\n' '\n\n122.600\xa0€\n' '\n\n104.500\xa0€\n'
#  '\n\n113.500\xa0€\n' '\n\n240.000\xa0€\n' '\n\n108.000\xa0€\n'
#  '\n\n319.409\xa0€\n' '\n\n231.000\xa0€\n' '\n\n360.000\xa0€\n'
#  '\n\n345.000\xa0€\n' '\n\n104.669\xa0€\n' '\n\n181.210\xa0€\n'
#  '\n\n247.520\xa0€\n' '\n\n154.000\xa0€\n' '\n\n282.000\xa0€\n'
#  '\n\n258.000\xa0€\n' '\n\n426.000\xa0€\n' '\n\n173.000\xa0€\n'
#  '\n\n348.000\xa0€\n' '\n\n98.500\xa0€\n' '\n\n113.000\xa0€\n'
#  '\n\n103.974\xa0€\n' '\n\n285.000\xa0€\n' '\n\n466.000\xa0€\n'
#  '\n\n450.000\xa0€\n' '\n\n114.000\xa0€\n' '\n\n235.000\xa0€\n'
#  '\n\n251.440\xa0€\n' '\n\n780.000\xa0€\n' '\n\n392.000\xa0€\n'
#  '\n\n356.000\xa0€\n' '\n\n183.000\xa0€\n' '\n\n79.990\xa0€\n'
#  '\n\n2.000\xa0€\n' '\n\n1.850\xa0€\n' '\n\n164.900\xa0€\n'
#  '\n\n77.700\xa0€\n' '\n\n1.680\xa0€\n' '\n\n203.300\xa0€\n'
#  '\n\n850\xa0€\n' '\n\n144.716\xa0€\n' '\n\n419.000\xa0€\n'
#  '\n\n204.470\xa0€\n' '\n\n64.800\xa0€\n' '\n\n152.000\xa0€\n'
#  '\n\n330.000\xa0€\n' '\n\n126.000\xa0€\n' '\n\n289.000\xa0€\n'
#  '\n\n127.500\xa0€\n' '\n\n143.000\xa0€\n' '\n\n62.000\xa0€\n'
#  '\n\n107.000\xa0€\n' '\n\n179.900\xa0€\n' '\n\n235.600\xa0€\n'
#  '\n\n7.000\xa0€\n' '\n\n63.900\xa0€\n' '\n\n166.000\xa0€\n'
#  '\n\n53.000\xa0€\n' '\n\n99.500\xa0€\n' '\n\n349.000\xa0€\n'
#  '\n\n595.000\xa0€\n' '\n\n84.400\xa0€\n' '\n\n131.400\xa0€\n'
#  '\n\n131.500\xa0€\n' '\n\n68.800\xa0€\n' '\n\n113.200\xa0€\n'
#  '\n\n115.900\xa0€\n' '\n\n88.800\xa0€\n' '\n\n83.400\xa0€\n'
#  '\n\n223.000\xa0€\n' '\n\n68.000\xa0€\n' '\n\n485.000\xa0€\n'
#  '\n\n13.990\xa0€\n' '\n\n194.000\xa0€\n' '\n\n250.000\xa0€\n'
#  '\n\n137.000\xa0€\n' '\n\n193.500\xa0€\n' '\n\n695.000\xa0€\n'
#  '\n\n154.999\xa0€\n' '\n\n390.000\xa0€\n' '\n\n246.000\xa0€\n'
#  '\n\n139.000\xa0€\n' '\n\n393.000\xa0€\n' '\n\n278.000\xa0€\n'
#  '\n\n310.000\xa0€\n' '\n\n214.000\xa0€\n' '\n\n369.000\xa0€\n'
#  '\n\n179.775\xa0€\n' '\n\n118.249\xa0€\n' '\n\n125.914\xa0€\n'
#  '\n\n98.539\xa0€\n' '\n\n116.059\xa0€\n' '\n\n120.439\xa0€\n'
#  '\n\n143.434\xa0€\n' '\n\n121.534\xa0€\n' '\n\n141.244\xa0€\n'
#  '\n\n155.540\xa0€\n' '\n\n91.000\xa0€\n' '\n\n150.015\xa0€\n'
#  '\n\n1.300.000\xa0€\n' '\n\n174.000\xa0€\n' '\n\n125.914,05\xa0€\n'
#  '\n\n118.249,05\xa0€\n' '\n\n143.434,05\xa0€\n' '\n\n116.059,05\xa0€\n'
#  '\n\n98.539,05\xa0€\n' '\n\n549.000\xa0€\n' '\n\n129.450\xa0€\n'
#  '\n\n197.300\xa0€\n' '\n\n121.534,05\xa0€\n' '\n\n141.244,05\xa0€\n'
#  '\n\n120.439,05\xa0€\n' '\n\n413.680\xa0€\n' '\n\n349.397\xa0€\n'
#  '\n\n129.226\xa0€\n' '\n\n202.043\xa0€\n' '\n\n189.851\xa0€\n'
#  '\n\n100.767,38\xa0€\n' '\n\n176.733\xa0€\n' '\n\n156.790,31\xa0€\n'
#  '\n\n104.000\xa0€\n' '\n\n281.380\xa0€\n' '\n\n180.320\xa0€\n'
#  '\n\n249.920\xa0€\n' '\n\n163.263\xa0€\n' '\n\n169.643\xa0€\n'
#  '\n\n152.713\xa0€\n' '\n\n385.588\xa0€\n' '\n\n121.000\xa0€\n'
#  '\n\n146.000\xa0€\n' '\n\n385.000\xa0€\n' '\n\n350.000\xa0€\n'
#  '\n\n375.000\xa0€\n' '\n\n117.990\xa0€\n' '\n\n78.500\xa0€\n'
#  '\n\n280.791\xa0€\n' '\n\n355.940\xa0€\n' '\n\n429.000\xa0€\n'
#  '\n\n205.000\xa0€\n' '\n\n89.900\xa0€\n' '\n\n217.160\xa0€\n'
#  '\n\n62.900\xa0€\n' '\n\n88.900\xa0€\n' '\n\n298.000\xa0€\n'
#  '\n\n495.000\xa0€\n' '\n\n198.000\xa0€\n' '\n\n69.990\xa0€\n'
#  '\n\n67.900\xa0€\n' '\n\n147.000\xa0€\n' '\n\n25.000\xa0€\n'
#  '\n\n247.185\xa0€\n' '\n\n470.630\xa0€\n' '\n\n174.990\xa0€\n'
#  '\n\n47.000\xa0€\n' '\n\n124.000\xa0€\n' '\n\n587.606\xa0€\n'
#  '\n\n401.900\xa0€\n' '\n\n568.090\xa0€\n' '\n\n152.670\xa0€\n'
#  '\n\n402.600\xa0€\n' '\n\n359.900\xa0€\n' '\n\n185.440\xa0€\n'
#  '\n\n244.000\xa0€\n' '\n\n189.100\xa0€\n' '\n\n343.238\xa0€\n'
#  '\n\n313.478\xa0€\n' '\n\n289.125\xa0€\n' '\n\n207.153\xa0€\n'
#  '\n\n252.338\xa0€\n' '\n\n246.038\xa0€\n' '\n\n143.775\xa0€\n'
#  '\n\n332.125\xa0€\n' '\n\n415.336\xa0€\n' '\n\n279.814\xa0€\n'
#  '\n\n64.900\xa0€\n' '\n\n94.900\xa0€\n' '\n\n267.000\xa0€\n'
#  '\n\n249.999\xa0€\n' '\n\n108.990\xa0€\n' '\n\n49.900\xa0€\n'
#  '\n\n109.870\xa0€\n' '\n\n394.800\xa0€\n' '\n\n775.700\xa0€\n'
#  '\n\n455.000\xa0€\n' '\n\n320.571\xa0€\n' '\n\n350.768\xa0€\n'
#  '\n\n675.877\xa0€\n' '\n\n116.500\xa0€\n' '\n\n355.600\xa0€\n'
#  '\n\n59.990\xa0€\n' '\n\n223.932\xa0€\n' '\n\n289.726\xa0€\n'
#  '\n\n159.442\xa0€\n' '\n\n156.119\xa0€\n' '\n\n153.000\xa0€\n'
#  '\n\n126.500\xa0€\n' '\n\n257.522\xa0€\n' '\n\n346.996\xa0€\n'
#  '\n\n346.653\xa0€\n' '\n\n37.200\xa0€\n' '\n\n181.000\xa0€\n'
#  '\n\n265.000\xa0€\n' '\n\n103.264\xa0€\n' '\n\n190.000\xa0€\n'
#  '\n\n430.000\xa0€\n' '\n\n490.000\xa0€\n' '\n\n550.000\xa0€\n'
#  '\n\n288.000\xa0€\n' '\n\n315.000\xa0€\n' '\n\n148.263\xa0€\n'
#  '\n\n494.900\xa0€\n' '\n\n480.000\xa0€\n' '\n\n340.000\xa0€\n'
#  '\n\n57.900\xa0€\n' '\n\n204.960\xa0€\n' '\n\n67.530\xa0€\n'
#  '\n\n69.927\xa0€\n' '\n\n268.165\xa0€\n' '\n\n255.792\xa0€\n'
#  '\n\n535.000\xa0€\n' '\n\n157.000\xa0€\n' '\n\n328.000\xa0€\n'
#  '\n\n448.500\xa0€\n' '\n\n530.000\xa0€\n' '\n\n475.000\xa0€\n'
#  '\n\n362.711\xa0€\n' '\n\n568.724\xa0€\n' '\n\n247.500\xa0€\n'
#  '\n\n175.500\xa0€\n' '\n\n197.600\xa0€\n' '\n\n207.600\xa0€\n'
#  '\n\n206.500\xa0€\n' '\n\n202.100\xa0€\n' '\n\n73.000\xa0€\n'
#  '\n\n127.892,50\xa0€\n' '\n\n76.500\xa0€\n' '\n\n252.337,50\xa0€\n'
#  '\n\n176.000\xa0€\n' '\n\n650.000\xa0€\n' '\n\n287.000\xa0€\n'
#  '\n\n71.000\xa0€\n' '\n\n145.002\xa0€\n' '\n\n156.354\xa0€\n'
#  '\n\n193.248\xa0€\n' '\n\n120.912\xa0€\n' '\n\n185.307\xa0€\n'
#  '\n\n163.598\xa0€\n' '\n\n139.803\xa0€\n' '\n\n379.000\xa0€\n'
#  '\n\n374.000\xa0€\n' '\n\n270.000\xa0€\n' '\n\n136.000\xa0€\n'
#  '\n\n172.000\xa0€\n' '\n\n467.607\xa0€\n' '\n\n394.000\xa0€\n'
#  '\n\n110.945\xa0€\n' '\n\n92.500\xa0€\n' '\n\n22.000\xa0€\n'
#  '\n\n232.900\xa0€\n' '\n\n154.520\xa0€\n' '\n\n114.964\xa0€\n'
#  '\n\n142.536\xa0€\n' '\n\n32.640\xa0€\n' '\n\n1.250.000\xa0€\n'
#  '\n\n86.900\xa0€\n' '\n\n1.900.000\xa0€\n' '\n\n720.000\xa0€\n'
#  '\n\n43.900\xa0€\n' '\n\n194.900\xa0€\n' '\n\n22.900\xa0€\n'
#  '\n\n89.500\xa0€\n' '\n\n129.999\xa0€\n']
# ['Skupna cena' 'Cena na m²']
# ['Prodam']
# ['Savinjska, Celje, Slavko Šlander'
#  'Osrednjeslovenska, Ljubljana Center, Center' 'Gorenjska, Tržič, Tržič'
#  'Savinjska, Slovenske Konjice, Slovenske Konjice'
#  'Osrednjeslovenska, Ljubljana Bežigrad, Bežigrad'
#  'Podravska, Kidričevo, Kidričevo' 'Osrednjeslovenska, Domžale, Domžale'
#  'Koroška, Podvelka, Podvelka' 'Osrednjeslovenska, Vrhnika, Vrhnika'
#  'Osrednjeslovenska, Ljubljana Bežigrad, Stožice'
#  'Savinjska, Velenje, Velenje' 'Podravska, Maribor, Nova Vas'
#  'Podravska, Dornava, Dornava' 'Podravska, Ptuj, Ptuj'
#  'Pomurska, Murska Sobota, Murska Sobota' 'Podravska, Starše, Prepolje'
#  'Jugovzhodna Slovenija, Kočevje, Kočevje' 'Podravska, Maribor, Center'
#  'Podravska, Maribor, Magdalena' 'Savinjska, Celje, Celje'
#  'Podravska, Maribor, Studenci' 'Podravska, Ruše, Bistrica ob Dravi'
#  'Izven Slovenije - Hrvaška, Zadarska, Vir'
#  'Pomurska, Moravske Toplice, Moravske Toplice'
#  'Savinjska, Celje, Nova vas' 'Primorsko-notranjska, Postojna, Postojna'
#  'Podravska, Maribor, Borštnikova ul.'
#  'Osrednjeslovenska, Ljubljana, Topniška'
#  'Podravska, Slovenska Bistrica, Slovenska Bistrica'
#  'Osrednjeslovenska, Ljubljana Šiška, Šiška'
#  'Koroška, Radlje ob Dravi, Radlje ob Dravi'
#  'Osrednjeslovenska, Ljubljana Center, Trnovo'
#  'Goriška, Nova Gorica, Nova Gorica'
#  'Koroška, Ravne na Koroškem, Ravne na Koroškem'
#  'Pomurska, Lendava, Lendava'
#  'Osrednjeslovenska, Ivančna Gorica, Ivančna Gorica'
#  'Savinjska, Prebold, Prebold' 'Savinjska, Celje, Savinja'
#  'Pomurska, Šalovci, Šalovci' 'Pomurska, Apače, Apače'
#  'Podravska, Maribor, Pobrežje' 'Savinjska, Braslovče, Gomilsko'
#  'Podravska, Maribor, Betnava' 'Obalno-kraška, Piran, Piran'
#  'Izven Slovenije - Hrvaška, Istrska, Pula' 'Savinjska, Celje, Lava'
#  'Podravska, Maribor okolica, Trčova'
#  'Izven Slovenije - Hrvaška, Istrska, Brtonigla'
#  'Podravska, Lenart v Slovenskih goricah, Lenart v Slovenskih goricah'
#  'Podravska, Maribor, Melje' 'Savinjska, Dobrna, Vinska Gorica'
#  'Podravska, Oplotnica, Oplotnica' 'Podravska, Maribor, Radvanje'
#  'Osrednjeslovenska, Ljubljana Vič Rudnik, Rudnik'
#  'Osrednjeslovenska, Litija, Litija' 'Zasavska, Trbovlje, Trbovlje'
#  'Osrednjeslovenska, Ljubljana Šiška, Dravlje'
#  'Savinjska, Šoštanj, Gaberke'
#  'Izven Slovenije - Hrvaška, Liško-senjska, Novalja'
#  'Podravska, Starše, Starše' 'Savinjska, Celje, Hudinja'
#  'Izven Slovenije - Hrvaška, Zadarska, Pag'
#  'Osrednjeslovenska, Ljubljana Center, Mirje'
#  'Obalno-kraška, Izola, Izola'
#  'Osrednjeslovenska, Ljubljana Vič Rudnik, Vič - Dolgi most'
#  'Podravska, Hoče, Hoče'
#  'Osrednjeslovenska, Ljubljana Center, Stara Ljubljana'
#  'Osrednjeslovenska, Kamnik, Kamnik' 'Podravska, Ruše, Ruše'
#  'Podravska, Maribor, Tezno' 'Podravska, Maribor, Koroška vrata'
#  'Podravska, Maribor okolica, Vrhov Dol'
#  'Jugovzhodna Slovenija, Trebnje, Trebnje'
#  'Pomurska, Gornja Radgona, Gornja Radgona' 'Podravska, Maribor, Tabor'
#  'Savinjska, Vojnik, Vojnik' 'Osrednjeslovenska, Domžale, Radomlje'
#  'Osrednjeslovenska, Ljubljana Šiška, Pržan'
#  'Obalno-kraška, Piran, Lucija' 'Pomurska, Radenci, Radenci'
#  'Podravska, Maribor okolica, Kamnica'
#  'Gorenjska, Škofja Loka, Škofja Loka'
#  'Podravska, Šentilj v Slovenskih goricah, Sladki Vrh'
#  'Jugovzhodna Slovenija, Šmarješke Toplice, Šmarješke Toplice'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Nove Fužine'
#  'Podravska, Maribor, Limbuš'
#  'Savinjska, Žalec, Šempeter v Savinjski dolini'
#  'Osrednjeslovenska, Ljubljana Bežigrad, BS 3'
#  'Osrednjeslovenska, Ljubljana Šiška, Spodnja Šiška'
#  'Gorenjska, Radovljica, Radovljica'
#  'Savinjska, Rogaška Slatina, Rogaška Slatina'
#  'Osrednjeslovenska, Ljubljana Šiška, Stegne'
#  'Goriška, Nova Gorica, Rožna Dolina' 'Savinjska, Šentjur, Svetelka'
#  'Koroška, Ribnica na Pohorju, Ribnica na Pohorju'
#  'Pomurska, Križevci, Križevci pri Ljutomeru'
#  'Savinjska, Šmarje pri Jelšah, Šmarje pri Jelšah'
#  'Posavska, Krško, Krško' 'Osrednjeslovenska, Logatec, Logatec'
#  'Pomurska, Ljutomer, Ljutomer' 'Podravska, Hoče, Rogoza'
#  'Savinjska, Polzela, Polzela'
#  'Osrednjeslovenska, Ljubljana Bežigrad, Črnuče' 'Koroška, Mežica, Mežica'
#  'Izven Slovenije - Hrvaška, Vukovarsko-sremska, Privlaka'
#  'Obalno-kraška, Koper, Koper'
#  'Podravska, Šentilj v Slovenskih goricah, Šentilj v Slovenskih goricah'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Kodeljevo'
#  'Izven Slovenije - Hrvaška, Istrska, Umag' 'Savinjska, Zreče, Zreče'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Fužine'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Moste'
#  'Savinjska, Celje, Center' 'Savinjska, Dobrna, Dobrna'
#  'Savinjska, Šentjur, Hrušovje'
#  'Gorenjska, Cerklje na Gorenjskem, Cerklje na Gorenjskem'
#  'Osrednjeslovenska, Ljubljana Moste Polje, BTC'
#  'Osrednjeslovenska, Domžale, Zgornje Jarše'
#  'Osrednjeslovenska, Ljubljana Vič Rudnik, Dolgi most'
#  'Obalno-kraška, Kozina, Kozina' 'Koroška, Prevalje, Zagrad'
#  'Jugovzhodna Slovenija, Metlika, Metlika' 'Gorenjska, Kranj, Kranj'
#  'Savinjska, Žalec, Žalec' 'Osrednjeslovenska, Dobrova, Dobrova'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Vodmat'
#  'Osrednjeslovenska, Domžale, Dragomelj'
#  'Osrednjeslovenska, Ljubljana Bežigrad, Črnuška gmajna'
#  'Savinjska, Vitanje, Vitanje' 'Zasavska, Zagorje ob Savi, Kisovec'
#  'Podravska, Benedikt, Sv. Trije Kralji v Slov. Gor.'
#  'Koroška, Slovenj Gradec, Slovenj Gradec'
#  'Podravska, Slovenska Bistrica, Pragersko' 'Podravska, Rače, Rače'
#  'Podravska, Benedikt, Benedikt'
#  'Osrednjeslovenska, Ljubljana Center, Prule'
#  'Koroška, Dravograd, Dravograd'
#  'Jugovzhodna Slovenija, Šentjernej, Gorenji Maharovec'
#  'Koroška, Vuzenica, Vuzenica' 'Savinjska, Radeče, Radeče'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Omišalj'
#  'Savinjska, Štore, Štore'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Studenec'
#  'Osrednjeslovenska, Šmartno pri Litiji, Mala Kostrevnica'
#  'Gorenjska, Bled, Bled' 'Gorenjska, Bohinj, Bohinjska Bistrica'
#  'Podravska, Lovrenc na Pohorju, Lovrenc na Pohorju'
#  'Podravska, Kungota, Pesnica'
#  'Podravska, Starše, Marjeta na Dravskem polju'
#  'Osrednjeslovenska, Moravče, Hrastnik'
#  'Savinjska, Rogaška Slatina, Podplat' 'Savinjska, Laško, Laško'
#  'Koroška, Mislinja, Mislinja' 'Savinjska, Žalec, Petrovče'
#  'Osrednjeslovenska, Log pri Brezovici, Dragomer'
#  'Osrednjeslovenska, Medvode, Medvode' 'Goriška, Idrija, Idrija'
#  'Jugovzhodna Slovenija, Dolenjske Toplice, Dolenjske Toplice'
#  'Savinjska, Podčetrtek, Podčetrtek' 'Gorenjska, Bohinj, Polje'
#  'Osrednjeslovenska, Ljubljana Šiška, Šentvid'
#  'Goriška, Nova Gorica, Trnovo pri Gorici' 'Podravska, Ormož, Ormož'
#  'Obalno-kraška, Koper, Ankaran' 'Obalno-kraška, Piran, Portorož'
#  'Izven Slovenije - Hrvaška, Šibensko-kninska, Murter'
#  'Osrednjeslovenska, Ljubljana Šiška, Koseze'
#  'Osrednjeslovenska, Ljubljana, Šmartno' 'Goriška, Ajdovščina, Ajdovščina'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Matulji'
#  'Izven Slovenije - Hrvaška, Zadarska, Zadar'
#  'Izven Slovenije - Hrvaška, Istrska, Vodnjan'
#  'Izven Slovenije - Hrvaška, Istrska, Poreč'
#  'Osrednjeslovenska, Škofljica, Lavrica'
#  'Izven Slovenije - Hrvaška, Splitsko-dalmatinska, Marina'
#  'Savinjska, Šentjur, Črnolica' 'Savinjska, Zreče, Planina na Pohorju'
#  'Savinjska, Rogaška Slatina, Ratanska vas'
#  'Obalno-kraška, Izola, Jagodje' 'Goriška, Nova Gorica, Solkan'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Dobrinj'
#  'Izven Slovenije - Hrvaška, Splitsko-dalmatinska, Okrug'
#  'Podravska, Pesnica pri Mariboru, Zgornji Jakobski Dol'
#  'Osrednjeslovenska, Brezovica pri Ljubljani, Brezovica pri Ljubljani'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Krk'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Poljane'
#  'Obalno-kraška, Komen, Komen'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Polje'
#  'Jugovzhodna Slovenija, Črnomelj, Črnomelj'
#  'Osrednjeslovenska, Ljubljana, UKC'
#  'Jugovzhodna Slovenija, Žužemberk, Žužemberk'
#  'Pomurska, Gornja Radgona, Aženski Vrh'
#  'Osrednjeslovenska, Ljubljana Vič Rudnik, Rožna dolina'
#  'Osrednjeslovenska, Ljubljana Bežigrad, Zupančičeva jama'
#  'Podravska, Miklavž na Dravskem polju, Miklavž na Dravskem polju'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Opatija'
#  'Gorenjska, Tržič, Pristava'
#  'Izven Slovenije - Hrvaška, Istrska, Novigrad'
#  'Izven Slovenije - Hrvaška, Istrska, Medulin'
#  'Podravska, Sv. Ana v Slovenskih goricah, Lokavec'
#  'Obalno-kraška, Sežana, Sežana'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Mali Lošinj'
#  'Gorenjska, Jesenice, Blejska Dobrava'
#  'Osrednjeslovenska, Ljubljana Šiška, Tacen'
#  'Izven Slovenije - Hrvaška, Splitsko-dalmatinska, Seget'
#  'Osrednjeslovenska, Dol pri Ljubljani, Dol pri Ljubljani'
#  'Podravska, Hajdina, Slovenja vas'
#  'Osrednjeslovenska, Ljubljana, Poštni center'
#  'Osrednjeslovenska, Ljubljana Bežigrad, Savsko naselje'
#  'Podravska, Ruše, Bezena'
#  'Osrednjeslovenska, Brezovica pri Ljubljani, Preserje'
#  'Osrednjeslovenska, Brezovica pri Ljubljani, Notranje Gorice'
#  'Izven Slovenije - Hrvaška, Splitsko-dalmatinska, Trogir'
#  'Obalno-kraška, Piran, Parecag' 'Osrednjeslovenska, Domžale, Vir'
#  'Gorenjska, Jesenice, Koroška Bela' 'Savinjska, Vransko, Vransko'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Nove Jarše'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Zalog'
#  'Obalno-kraška, Izola, Korte'
#  'Osrednjeslovenska, Ljubljana Šiška, Litostroj'
#  'Savinjska, Solčava, Solčava' 'Posavska, Sevnica, Sevnica'
#  'Gorenjska, Železniki, Železniki'
#  'Osrednjeslovenska, Ljubljana Šiška, Brod'
#  'Osrednjeslovenska, Ljubljana Vič Rudnik, Kolezija'
#  'Podravska, Maribor, Ostalo'
#  'Izven Slovenije - Hrvaška, Istrska, Tar-Vabriga'
#  'Savinjska, Slovenske Konjice, Spodnje Preloge'
#  'Savinjska, Vojnik, Konjsko' 'Savinjska, Šentjur, Bezovje pri Šentjurju'
#  'Pomurska, Apače, Žepovci'
#  'Podravska, Sv. Ana v Slovenskih goricah, Krivi Vrh'
#  'Koroška, Prevalje, Prevalje'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Malinska-dubašnica'
#  'Osrednjeslovenska, Ljubljana Šiška, Draveljska gmajna'
#  'Podravska, Selnica ob Dravi, Zgornja Selnica'
#  'Savinjska, Šentjur, Šentjur' 'Savinjska, Žalec, Kasaze'
#  'Jugovzhodna Slovenija, Novo mesto, Novo mesto'
#  'Podravska, Markovci, Markovci' 'Osrednjeslovenska, Trzin, Trzin'
#  'Osrednjeslovenska, Grosuplje, Tlake'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Kraljevica'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Lovran'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Crikvenica'
#  'Izven Slovenije - Hrvaška, Zadarska, Biograd na Moru'
#  'Osrednjeslovenska, Domžale, Škrjančevo' 'Posavska, Krško, Senovo'
#  'Savinjska, Šmarje pri Jelšah, Cerovec pri Šmarju'
#  'Izven Slovenije - Hrvaška, Istrska, Buje'
#  'Podravska, Šentilj v Slovenskih goricah, Selnica ob Muri'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Novi Vinodolski'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Rab'
#  'Izven Slovenije - Hrvaška, Primorsko-goranska, Opatija - Okolica'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Zelena jama'
#  'Podravska, Maribor, Košaki' 'Podravska, Slovenska Bistrica, Laporje'
#  'Pomurska, Ljutomer, Stara cesta' 'Podravska, Ormož, Pušenci'
#  'Goriška, Tolmin, Poljubinj' 'Goriška, Vipava, Vipava'
#  'Podravska, Hoče, Radizel'
#  'Osrednjeslovenska, Ljubljana Moste Polje, Tabor']
# ['V večstanovanjski stavbi' nan 'V hiši']
# ['1.' 'Pritličje' '7.' nan '2.' '3.' '4.' 'Mansarda' '5.' 'Klet'
#  'Visoko pritličje' '8.' '6.' '12.' '9.' 'Penthouse' '11.' '13.']
# [ 2.  4.  5.  7. nan  3. 10.  8.  1. 14. 16. 22.  6. 12. 11. 15. 13.]
# ['3-sobno' 'Garsonjera' '2-sobno' '1,5-sobno' nan '2,5-sobno' 'Apartma'
#  '4,5-sobno' '3,5-sobno' '4-sobno' '1-sobno' '6 in večsobno' '5-sobno'
#  'Drugo']
# ['86,00 m²' '28,60 m²' '11,00 m²' nan '53,50 m²' '59,00 m²' '27,00 m²'
#  '52,00 m²' '60,20 m²' '38,00 m²' '78,00 m²' '24,00 m²' '14,00 m²'
#  '80,00 m²' '43,00 m²' '200,00 m²' '100,00 m²' '194,00 m²' '96,00 m²'
#  '62,00 m²' '70,00 m²' '26,09 m²' '49,00 m²' '118,00 m²' '90,30 m²'
#  '66,50 m²' '43,50 m²' '65,00 m²' '44,90 m²' '75,00 m²' '45,40 m²'
# [nan 'Vrt/dvorišče, Lopa za shranjevanje, Vrtna uta' 'Vrt/dvorišče'
#  'Lopa za shranjevanje'
#  'Vrt/dvorišče, Lopa za shranjevanje, Vrtna uta, Žar, Bazen'
#  'Vrt/dvorišče, Lopa za shranjevanje'
#  'Vrt/dvorišče, Lopa za shranjevanje, Vrtna uta, Žar'
#  'Vrt/dvorišče, Zimski vrt, Lopa za shranjevanje, Vrtna uta, Žar, Bazen'
#  'Vrt/dvorišče, Vrtna uta' 'Zimski vrt' 'Vrtna uta' 'Žar, Bazen' 'Bazen'
#  'Vrt/dvorišče, Lopa za shranjevanje, Žar' 'Vrt/dvorišče, Žar'
#  'Vrt/dvorišče, Zimski vrt']
# [nan 'PS00491JP' '943' '5214' '100108-484' '101179-306' '490271003-298'
#  'GALEA 2021/391' '1052' 'GALEA 2021/395' '1053' 'P2' '1054'
#  'GALEA 2021/409' 'GALEA 2021/396' 'GALEA 2021/397' 'GALEA 2021/399'
#  'GALEA 2021/401' 'GALEA 2021/402' 'GALEA 2021/400' 'GALEA 2021/407'
#  'GALEA 2021/404' 'GALEA 2021/406' 'GALEA 2021/410' 'GALEA 2021/412'
#  'GALEA 2021/411' 'GALEA 2021/414' 'PS38621907BM' 'PS4646642PB'
#  '107209-56' 'PS4646054MR' 'GALEA 2021/405' 'GALEA 2021/403'
#  'GALEA 2021/398' 'J3' 'PS4645466MR - 5' 'PS4646640MM' '101108-483'
#  '107209-55' 'PS38621906PV' 'PS38621905PV' 'PS00714PD' 'KODA: P1283CE'
#  'GALEA 2021/389' '5n5-I' '2N1' 'PS4646466MR - 1' 'PS4646465MR - 2'
#  'PS4646464MR - 3' 'PS4646463MR - 4' 'PS4646462MR - 5' 'PS4646461MR - 6'
#  'PS4646460MR - 7' 'PS4646459MR - 8' 'PS4646458MR - 9' 'PS4646457MR - 10'
#  'PS4646456MR - 11' 'PS4646455MR - 12' 'PS4646454MR - 13'
#  'PS4646452MR - 15' 'PS4646451MR - 16' 'PS4646450MR - 17'
#  'PS4646449MR - 18' 'PS4646626KM' 'PS4646576AP' '101179-302' '101179-304'
#  '101179-298' '101179-299' '101179-303' '101179-300' '101179-301'
#  'PS38621903BM' '490191084-119' '490191084-121' '490191084-120' 'PE9430'
#  '100108-469' '100104-328' '100103-176' '100186-67' '100155-249'
#  'GALEA 2021/392' '100787' 'PS4646408DL' 'PS4646624MM' 'PS4646623AP'
#  'PS4646622AP' 'PS4646589DL' 'PS4646595MR' 'PS4646574BJ' 'PS38621902AS'
#  'KODA: P1083CT' 'KODA: P1058NKM' '490191084-118' 'P52ŠK' '100770' 'M55'
#  'SP3424' 'L214' '490191069-80' '070320211' '101179-297' '490281015-392'
#  'SP3322' 'R58' '100105-226' '490191104-18' 'P32ŠL' '490281027-64'
#  '107220-11' '107207-9' '107193-65' 'PS142' 'G189' 'RE ID 2120-010'
#  '100155-251' 'PS00711PD' 'S-32/2021' '100108-346' '100108-345'
#  '100108-344' '107210-62' 'PS00709MN' '490281026-102' '490191096-18'
#  'PS4646527BJ' '8739' '100715' '202103' 'PS4646512MR' 'RE ID 2120-002'
#  'RE ID 2120-007' 'RE ID 2120-017' 'RE ID 2120-015' 'RE ID 2120-014'
#  'RE ID 2120-013' 'RE ID 2120-012' 'RE ID 2120-011' 'RE ID 2120-009'
#  '100761' 'SP3280' 'R53' '100689' 'PE9410' '0151/20-S/P_4/6_20'
#  '0003/17-S/K_1/6_20' 'KODA: P1054AKM' 'RE ID 2017-007' 'L207'
#  'PS4646552MM' 'KODA: P1053KAM' 'PS4646536MM' '2012-1011' 'GALEA 2021/379'
#  '100108-458' '100108-439' '100108-301' '100107-119' '100104-456'
#  '100104-455' '100155-237' 'PS4646163MR' 'KODA: P1284DO' '100735' 'SP3001'
#  '100713' '100712' '100710' 'S101' 'PS38621891PV' 'PS38621890AS'
#  'PS38621888AS' 'PS38621882AS' 'PS38621881AS' 'PS38621880AS'
#  'PS38621879AS' 'PS38621878AS' 'PS38621877AS' 'PS38621876AS'
#  'PS38621875AS' 'PS38621872AS' 'PS38621871AS' 'PS38621870AS' 'PS00703MN'
#  'PS00698PG' 'PS00696MN' 'PS00695MN' 'PS00559FP' 'PS00557FP' 'PS4646517SS'
#  'PS4646514PB' 'PS4646480DL-18' 'PS4646480DL-12' 'PS4645730AB'
#  'GALEA 2021/376' '1032' '1031' 'PS4646480DL-1' 'PS4646480DL-15'
#  'PS4646480DL-17' 'PS4646480DL-11' 'PS4646480DL-10' 'PS4646480DL-9'
#  'PS4646480DL-7' 'PS4646480DL-5' 'PS4646480DL-3' 'PS4646480DL-2'
#  'PS4646392MR' 'PS4646505SS' 'PS4646491BJ' 'PS4646481PB' 'Koda: P1283VR'
#  'GALEA 2020/363' '101157-394' '101216-21' '101215-49' 'PS4646504BJ'
#  '100714' 'GALEA 2020/308' '2012-945' '101179-289' '101179-288'
#  '101215-48' 'PS4646109BJ-4' 'PS4646109BJ-3' 'PS4646109BJ-2' 'PS4646474MM'
#  '100669' '100693' '2012-1009' '100692' '101179-282' '100690' '101108-425'
#  '100685' '100671' '100677' '100104-458' '100155-236' '100104-459'
#  '100155-235' '100104-457' '100104-454' '100155-239' '100155-240'
#  '100155-238' '100673' 'P-002-21' 'PS4646462MM' 'GALEA 2020/293'
#  'S-2/2021' 'PS4646413MR' '101210-52' '100664' 'ST 4ss B53' 'ST 4ss B113'
#  '101215-41' '101215-40' '101215-39' '106166-209' '111213-63' '101179-275'
#  '101215-47' 'P-055-20' '107209-35' '107210-27' '107207-46' '107209-17'
#  'PS38621810BM' 'S-151/2020-1' '100653' '100650' '100646' 'PS4646432ZM'
#  '107198-125' 'GALEA 2020/342' 'GALEA 2020/328' 'GALEA 2020/327'
#  'GALEA 2020/325' 'GALEA 2020/322' 'GALEA 2020/321' 'GALEA 2020/320'
#  'GALEA 2020/319' 'GALEA 2020/317' 'Galea 2020/347' 'GALEA 2020/314'
#  'GALEA 2020/313' 'GALEA 2020/312' 'PS4646428SS' '2SSTK' '101215-42'
#  'KODA: P1058NKA' 'GALEA 2020/337' 'GALEA 2020/334' 'PS4646325BJ'
#  'PS4646343BJ' 'GALEA 2020/303' 'PS38621859BM' 'ST 2ss A122' 'PS4646346DS'
#  '101216-12' 'GALEA 2019/102' 'GALEA 2020/295' '3SSČIRČE' 'PS4646415ZM'
#  'PS4646413MM' 'GALEA 2019/178' '100186-64' 'SP3137' 'PS00681MN'
#  '101177-132' '107193-11' '101215-35' '101215-36' '101210-49' '101210-44'
#  '107210-6' '107209-3' '107209-32' '107209-26' '107209-29' '107209-36'
#  '107198-37' '107198-78' '107207-20' '107209-23' '107209-42' '107209-8'
#  '107209-9' '107209-19' '107209-20' '107209-21' '107209-18' '107207-35'
#  '107198-110' '107198-118' '107198-112' '107198-117' '107198-114'
#  '107198-109' '107198-115' '107198-111' '107198-116' '101191-22'
#  '101215-37' '101191-21' 'PS4646354MR' '100120-146' '100105-193'
#  '100181-175' '100108-286' '100195-87' 'PS4646067DL' 'PS4645290MR'
#  'PS4646381SS' 'PS38621836BM' 'PE9415' '101216-7' '101216-6'
#  'RE ID 42-054' '101145-226' '101145-207' '101145-227' '101215-26'
#  'PS4646262KC' '111213-56' 'A56' '396' 'PS4646121MR' 'PS4646112BJ'
#  'PS4646105BJ' 'PS4646098BJ' 'PS4646097BJ' 'PS4645614DS' 'PH4645541-2DS'
#  'PS4645499DL' 'PS4646096BJ-2' 'PS4645303RD' 'PS4644854DS' '101179-264'
#  '101215-23' '101216-2' '101179-205' 'PS133' 'PS134' '2012-1017' '100573'
#  '5147' '100443' '100442' '100330' '100438' '100421' 'PS38621844AS'
#  '100452' '100489' '100497' '100504' '100512' '100520' '100507' 'J2'
#  'S021020D' 'PS38621839AS' 'C-J3-P-S2' 'PS4646277ZM' 'PS4646275ZM' 'J1'
#  '111213-52' '101179-257' '936' 'PE9397' '733' 'PS0072TA' '202036'
#  'S-94/2020' '8679' 'B225' '979' 'PS00665MN' 'RE ID 2017-005'
#  'RE ID 2017-001' 'RE ID 2017-004' 'RE ID 2017-002' 'RE ID 2017-008'
#  'RE ID 2017-003' 'RE ID 2017-006' '2019' '107209-22' '8697' '101143-165'
#  'PS01008AD' 'PS01005AD' 'S130720A' 'S230919A' 'S070520B' '212-930'
#  'S070520A' 'S081219A' 'S160719A' 'S031019A' 'S040719A' '969' 'S211019B'
#  'S060319A' 'S070720B' 'S070617D' 'PS00655PD' '101215-1' '101215-6' '948'
#  'PS096' '5124' 'PS38621786PV' '101179-246' 'PS095' '950' 'RE ID 519-018'
#  'RE ID 519-003' 'RE ID 519-007' 'RE ID 519-011' 'RE ID 519-010'
#  'RE ID 519-016' 'KODA: P5083SC' 'G180' '935' 'P1515SJ' '106166-140'
#  '106165-63' '100366' '100390' '100332' '100042' '100406' '100090'
#  '100088' '100310' '100395' '100167' '106165-102' '2012-996' 'R32'
#  '2012-991' '8684' 'R30' '2012-993' '106166-194' '2012-992' '2012'
#  '106166-84' '101108-424' '101108-432' '101199-48' '101179-209'
#  '101199-61' '100151-26' '899' 'PS38621744PV' 'R24' 'PE9332' 'PS00628MN'
#  '8633' '8481' '8478' '8371' 'L200' 'S92' 'TPStaraC49NSV' 'PS0016TA'
#  'PS00178UL' 'PS00170AM' 'PS00161AM' 'PS01646ZH' 'PS00622MN' 'PS00621MN'
#  'PS00620MN' 'PS38621673SP' 'PS38621585PV' '20160512GUYPG' 'RE ID 1269'
#  'RE ID 1343' 'RE ID 2131' 'RE ID 448' 'RE ID 707' 'RE ID 2016'
#  'RE ID 6072' 'RE ID 988' 'RE ID 6071' 'RE ID 6069' '6081' 'RE ID 0891'
#  '882' 'B224' '2006' 'A1' '449' '291' 'J75' 'P-018-14']

# %%
# Objavljen > objavljen posted_date + posted_time...
def prepareFeatures (df): 
    a = {}
    main_df = pd.DataFrame()
    
    for i in tqdm(range(0,len(df))):
        a['AD_ID'] = df.iloc[i]['Šifra oglasa']

        a['posted_date'] = str(df.iloc[i]['Objavljen '].split('dne')[0])
        a['posted_time'] = str(df.iloc[i]['Objavljen '].split('dne')[1])

        a['shown'] = int(df.iloc[i]['Število prikazov oglasa'].split('-')[0])

        
        price = 0 if df.iloc[i]['Cena'] == '\npodogovoru' else int(df.iloc[i]['Cena'].split('\n')[2].split('\xa0')[0].replace('.','').split(',')[0])
        a['price'] = price
        a['currency'] = 'none' if df.iloc[i]['Cena'] == '\npodogovoru' else 'Euro'

        a['ptype'] = str('cumulative') if df.iloc[i]['Vrsta cene'] == 'Skupna cena' else 'perM2'

        a['l_region'] = str(df.iloc[i]['Lokacija'].split(',')[0].replace('š','s').replace('č','c').replace('ž','z').replace('Š','S').replace('Č','C').replace('Ž','Z'))
        a['l_2'] = str(df.iloc[i]['Lokacija'].split(',')[1].replace(' ', '').replace('š','s').replace('č','c').replace('ž','z').replace('Š','S').replace('Č','C').replace('Ž','Z'))
        a['l_3'] = str(df.iloc[i]['Lokacija'].split(',')[2].replace(' ', '').replace('š','s').replace('č','c').replace('ž','z').replace('Š','S').replace('Č','C').replace('Ž','Z'))

        a['sits_in'] = str(df.iloc[i]['Umeščenost stanovanja']).replace('š','s').replace('č','c').replace('ž','z').replace('Š','S').replace('Č','C').replace('Ž','Z')

        a['lvl'] = 0 if str(df.iloc[i]['Nadstropje']) == 'nan' else 'P' if df.iloc[i]['Nadstropje'] == 'Pritličje' else 'K' if df.iloc[i]['Nadstropje'] == 'Klet' else     'M' if df.iloc[i]['Nadstropje'] == 'Mansarda' else    'VP' if df.iloc[i]['Nadstropje'] == 'Visoko pritličje' else df.iloc[i]['Nadstropje'].split('.')[0] 

        a['t_lvl'] = 0 if str(df.iloc[i]['Skupno število nadstropij v stavbi']) == 'nan' else int(df.iloc[i]['Skupno število nadstropij v stavbi'])

        a['flat_type'] = df.iloc[i]['Vrsta stanovanja'].replace('š','s').replace('č','c').replace('ž','z').replace('Š','S').replace('Č','C').replace('Ž','Z') if str(df.iloc[i]['Vrsta stanovanja']) != 'nan' else 'none'
        
        size = 0 if str(df.iloc[i]['Bivalna površina']) == 'nan' else int(df.iloc[i]['Bivalna površina'].split(',')[0].replace('.',''))
        a['sizeM2'] = size
        
        net_size = 0 if str(df.iloc[i]['Neto površina']) == 'nan' else int(df.iloc[i]['Neto površina'].split(',')[0].replace('.',''))
        a['net_sizeM2'] = net_size
        
        a['price/sizeM2'] = price/size if int(size) != 0 else 0
        a['price/net_sizeM2']  = price/net_size if net_size != 0 else 0
        
        a['year_built'] = 0 if str(df.iloc[i]['Leto izgradnje*']) == 'nan' else df.iloc[i]['Leto izgradnje*']

        a['year_ren'] = 0 if str(df.iloc[i]['Leto zadnje prenove']) == 'nan' else df.iloc[i]['Leto zadnje prenove']

        a['condition'] = str(df.iloc[i]['Opremljenost in stanje']).replace('š','s').replace('č','c').replace('ž','z').replace('Š','S').replace('Č','C').replace('Ž','Z')

        a['en_eff'] = 'None' if str(df.iloc[i]['Energetski razred']) == 'nan'else df.iloc[i]['Energetski razred'].split(' ')[0] + df.iloc[i]['Energetski razred'].split(' ')[-1] if str(df.iloc[i]['Energetski razred'].split(' ')[-1]) == 'HR' else  df.iloc[i]['Energetski razred'].split(' ')[0]

        a['switch'] = 0 if str(df.iloc[i]['Možnost menjave']) == 'nan' else 1 if df.iloc[i]['Možnost menjave'] == 'Možna menjava za drugo nepremičnino' else 0 if df.iloc[i]['Možnost menjave'] == 'Menjava za drugo nepremičnino ni možna'  else np.nan

        a['park_spots'] =  0 if df.iloc[i]['Število parkirnih mest']  == 'brez pripadajočega parkirišča' else int(df.iloc[i]['Število parkirnih mest'].split('+')[0]) if str(df.iloc[i]['Število parkirnih mest']) != 'nan' else 0
       
        a['balcony'] = 1 if str(df.iloc[i]['Balkon / terasa / atrij']) != 'nan' else 0
        a['garden'] = 1 if str(df.iloc[i]['Zunanje površine in oprema']) != 'nan' else 0
        
        a_df = pd.DataFrame.from_dict([a])
        main_df = pd.concat([main_df,a_df],axis=0, ignore_index=True)
    return main_df

# %%
data_prep = prepareFeatures(data)
data_prep.head(5)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1188/1188 [00:11<00:00, 100.48it/s]
#      AD_ID posted_date posted_time  shown   price currency       ptype  \
# 0  6523968  14.03.2021       18:49     57  192000     Euro  cumulative
# 1  6523894  14.03.2021       18:39     29  134500     Euro  cumulative
# 2  6523589  14.03.2021       18:07     33   29500     Euro  cumulative
# 3  6523431  14.03.2021       17:47     34  120000     Euro  cumulative
# 4  6523190  14.03.2021       17:16     23  180000     Euro  cumulative
#
#             l_region                l_2               l_3  ... price/sizeM2  \
# 0          Savinjska              Celje     SlavkoSlander  ...  2232.558140
# 1  Osrednjeslovenska    LjubljanaCenter            Center  ...  4803.571429
# 2          Gorenjska              Trzic             Trzic  ...  2681.818182
# 3          Savinjska   SlovenskeKonjice  SlovenskeKonjice  ...     0.000000
# 4  Osrednjeslovenska  LjubljanaBezigrad          Bezigrad  ...  3396.226415
#
#   price/net_sizeM2  year_built year_ren             condition  en_eff  switch  \
# 0      1828.571429      2004.0      0.0                   nan    None       0
# 1      4637.931034      1908.0   2020.0  Popolnoma opremljeno      EI       1
# 2      2681.818182      1961.0      0.0                   nan       E       0
# 3      1714.285714      2020.0      0.0          Neopremljeno      A2       0
# 4         0.000000      1988.0      0.0                   nan    None       0
#
#    park_spots  balcony  garden
# 0           0        0       0
# 1           0        0       0
# 2           0        0       0
# 3           7        1       0
# 4           0        1       0
#
# [5 rows x 26 columns]

# %%
data_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188 entries, 0 to 1187
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AD_ID             1188 non-null   int64
#  1   posted_date       1188 non-null   object
#  2   posted_time       1188 non-null   object
#  3   shown             1188 non-null   int64
#  4   price             1188 non-null   int64
#  5   currency          1188 non-null   object
#  6   ptype             1188 non-null   object
#  7   l_region          1188 non-null   object
#  8   l_2               1188 non-null   object
#  9   l_3               1188 non-null   object
#  10  sits_in           1188 non-null   object
#  11  lvl               1188 non-null   object
#  12  t_lvl             1188 non-null   int64
#  13  flat_type         1188 non-null   object
#  14  sizeM2            1188 non-null   int64
#  15  net_sizeM2        1188 non-null   int64
#  16  price/sizeM2      1188 non-null   float64
#  17  price/net_sizeM2  1188 non-null   float64
#  18  year_built        1188 non-null   float64
#  19  year_ren          1188 non-null   float64
#  20  condition         1188 non-null   object
#  21  en_eff            1188 non-null   object
#  22  switch            1188 non-null   int64
#  23  park_spots        1188 non-null   int64
#  24  balcony           1188 non-null   int64
#  25  garden            1188 non-null   int64
# dtypes: float64(4), int64(10), object(12)
# memory usage: 241.4+ KB

# %%
df_col_dtypes = {
    'AD_ID':  'int32',
    'posted_date': 'str',
    'posted_time': 'str',
'shown': 'int32',
'price': 'int64',
'currency': '|S80',
'ptype' : '|S',
'l_region': '|S',
'l_2': '|S',
'l_3': '|S',
'sits_in': '|S',
'lvl': '|S',
't_lvl': 'int32',
'flat_type': '|S',
'sizeM2': 'int32',
'net_sizeM2': 'int32',
'price/sizeM2': 'int32',
'price/net_sizeM2': 'int32',
'year_built': 'int32',
'year_ren': 'int32',
'condition': '|S',
'en_eff': '|S',
'switch': 'int32',
'park_spots': 'int32',
'balcony': 'int32',
'garden': 'int32',
    
}

# %%
data_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188 entries, 0 to 1187
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AD_ID             1188 non-null   int64
#  1   posted_date       1188 non-null   object
#  2   posted_time       1188 non-null   object
#  3   shown             1188 non-null   int64
#  4   price             1188 non-null   int64
#  5   currency          1188 non-null   object
#  6   ptype             1188 non-null   object
#  7   l_region          1188 non-null   object
#  8   l_2               1188 non-null   object
#  9   l_3               1188 non-null   object
#  10  sits_in           1188 non-null   object
#  11  lvl               1188 non-null   object
#  12  t_lvl             1188 non-null   int64
#  13  flat_type         1188 non-null   object
#  14  sizeM2            1188 non-null   int64
#  15  net_sizeM2        1188 non-null   int64
#  16  price/sizeM2      1188 non-null   float64
#  17  price/net_sizeM2  1188 non-null   float64
#  18  year_built        1188 non-null   float64
#  19  year_ren          1188 non-null   float64
#  20  condition         1188 non-null   object
#  21  en_eff            1188 non-null   object
#  22  switch            1188 non-null   int64
#  23  park_spots        1188 non-null   int64
#  24  balcony           1188 non-null   int64
#  25  garden            1188 non-null   int64
# dtypes: float64(4), int64(10), object(12)
# memory usage: 241.4+ KB

# %%
def data_fix_types(df, colname_types = df_col_dtypes):
    fixed_df = df    
    
    for column in tqdm(df.columns):
        #print(column)
        typ =colname_types[column]
        fixed_df[column] = df[column].astype(typ)
        
    return fixed_df

# %%
data_tfix = data_fix_types(data_prep)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 1856.93it/s]

# %%
data_tfix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188 entries, 0 to 1187
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AD_ID             1188 non-null   int32
#  1   posted_date       1188 non-null   object
#  2   posted_time       1188 non-null   object
#  3   shown             1188 non-null   int32
#  4   price             1188 non-null   int64
#  5   currency          1188 non-null   |S80
#  6   ptype             1188 non-null   |S10
#  7   l_region          1188 non-null   |S25
#  8   l_2               1188 non-null   |S25
#  9   l_3               1188 non-null   |S25
#  10  sits_in           1188 non-null   |S24
#  11  lvl               1188 non-null   |S9
#  12  t_lvl             1188 non-null   int32
#  13  flat_type         1188 non-null   |S13
#  14  sizeM2            1188 non-null   int32
#  15  net_sizeM2        1188 non-null   int32
#  16  price/sizeM2      1188 non-null   int32
#  17  price/net_sizeM2  1188 non-null   int32
#  18  year_built        1188 non-null   int32
#  19  year_ren          1188 non-null   int32
#  20  condition         1188 non-null   |S20
#  21  en_eff            1188 non-null   |S7
#  22  switch            1188 non-null   int32
#  23  park_spots        1188 non-null   int32
#  24  balcony           1188 non-null   int32
#  25  garden            1188 non-null   int32
# dtypes: bytes104(1), bytes160(1), bytes192(1), bytes200(3), bytes56(1), bytes640(1), bytes72(1), bytes80(1), int32(13), int64(1), object(2)
# memory usage: 364.4+ KB

# %%
data_prep.head()
#data_tfix.head()
# Out:
#      AD_ID  posted_date  posted_time  shown   price  currency  ptype  \
# 0  6523968           89          407     57  192000         0      0
# 1  6523894           89          402     29  134500         0      0
# 2  6523589           89          392     33   29500         0      0
# 3  6523431           89          385     34  120000         0      0
# 4  6523190           89          370     23  180000         0      0
#
#    l_region  l_2  l_3  ...  price/sizeM2  price/net_sizeM2  year_built  \
# 0        11    7  195  ...          2232              1828        2004
# 1         6   43   22  ...          4803              4637        1908
# 2         0  110  229  ...          2681              2681        1961
# 3        11   97  199  ...             0              1714        2020
# 4         6   42    9  ...          3396                 0        1988
#
#    year_ren  condition  en_eff  switch  park_spots  balcony  garden
# 0         0          5      18       0           0        0       0
# 1      2020          3      12       1           0        0       0
# 2         0          5      10       0           0        0       0
# 3         0          2       1       0           7        1       0
# 4         0          5      18       0           0        1       0
#
# [5 rows x 26 columns]

# %%
#Plot missing values 
def plot_missing(df):
    # Find columns having missing values and count
    missing = df.isnull().sum()
    missing = missing[missing > 0]
    #missing.sort_values(inplace=True)
    
    # Plot missing values by count 
    missing.plot.bar(figsize=(12,8))
    plt.xlabel('Columns with missing values')
    plt.ylabel('Count')
    
    # search for missing data
    import missingno as msno
    msno.matrix(df=df, figsize=(16,8), color=(0,0.2,1))
    
plot_missing(data_tfix)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-8823d1356fe4> in <module>
#      15     msno.matrix(df=df, figsize=(16,8), color=(0,0.2,1))
#      16
# ---> 17 plot_missing(data_tfix)
#
# <ipython-input-81-8823d1356fe4> in plot_missing(df)
#       7
#       8     # Plot missing values by count
# ----> 9     missing.plot.bar(figsize=(12,8))
#      10     plt.xlabel('Columns with missing values')
#      11     plt.ylabel('Count')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1105         other axis represents a measured value.
#    1106         """
# -> 1107         return self(kind="bar", x=x, y=y, **kwargs)
#    1108
#    1109     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     276         for ax in self.axes:
#     277             self._post_plot_logic_common(ax, self.data)
# --> 278             self._post_plot_logic(ax, self.data)
#     279
#     280     def _args_adjust(self):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _post_plot_logic(self, ax, data)
#    1459         name = self._get_index_name()
#    1460
# -> 1461         s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1462         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1463
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
#trying out some filtering:
data_prep_filtered1 = data_prep.loc[(data_prep['price']>50000) & (data_prep['price']<100000) & (data_prep['sizeM2']>80)]
data_prep_filtered1.head()
# Out:
#       AD_ID posted_date posted_time shown    price currency       ptype  \
# 17  3174984  14.03.2021       08:50  2045  99900.0        €  cumulative
# 19  1452932  14.03.2021       08:20  3332  98900.0        €  cumulative
# 20  6515431  14.03.2021       00:15    55  90000.0        €  cumulative
# 59  6504189  12.03.2021       10:42    34  92177.0        €  cumulative
# 93  6492171  11.03.2021       00:13   781  74270.0        €  cumulative
#
#      l_region      l_2     l_3  ... price/sizeM2 price/net_sizeM2  year_built  \
# 17  Podravska  Maribor  Center  ...          NaN              NaN      1945.0
# 19  Podravska  Maribor  Center  ...          NaN              NaN      1919.0
# 20  Savinjska    Celje   Celje  ...   937.500000       937.500000      1700.0
# 59   Pomurska    Apače   Apače  ...          NaN              NaN      2021.0
# 93  Podravska     Ptuj    Ptuj  ...   558.421053       558.421053      1880.0
#
#    year_ren         condition  en_eff  switch  park_spots  balcony  garden
# 17   2018.0               NaN     NaN     NaN         NaN        0       0
# 19      NaN               NaN      EI     NaN         NaN        0       0
# 20   2020.0               NaN     NaN     NaN         NaN        0       0
# 59      NaN               NaN      EI     NaN         NaN        1       0
# 93   2010.0  Delno opremljeno     NaN     NaN           0        0       0
#
# [5 rows x 26 columns]

# %%
data_prep_filtered2= data_prep.loc[(data_prep['sizeM2'].isnull()) & (data_prep['net_sizeM2'].isnull()) & (data_prep['sits_in'].isnull())]
data_prep_filtered2
# Out:
#        AD_ID posted_date posted_time shown      price currency       ptype  \
# 10   6521099  14.03.2021       12:51   479   130000.0        €  cumulative
# 36   6507148  13.03.2021       00:13   163    40000.0        €  cumulative
# 140  6484624  10.03.2021       00:12    40   655000.0        €  cumulative
# 141  6484623  10.03.2021       00:12    65  1884000.0        €  cumulative
# 142  6484622  10.03.2021       00:12    42   489000.0        €  cumulative
# ..       ...         ...         ...   ...        ...      ...         ...
# 485  6384167  25.02.2021       00:21   315   235000.0        €  cumulative
# 486  6384143  25.02.2021       00:21   539   125000.0        €  cumulative
# 487  6384138  25.02.2021       00:21   403   165000.0        €  cumulative
# 488  6384080  25.02.2021       00:21   174   251440.0        €  cumulative
# 622  6307365  15.02.2021       12:32    75        0.0        €  cumulative
#
#               l_region              l_2             l_3  ... price/sizeM2  \
# 10           Savinjska          Velenje         Velenje  ...          NaN
# 36             Koroška    RadljeobDravi   RadljeobDravi  ...          NaN
# 140  Osrednjeslovenska  LjubljanaCenter  StaraLjubljana  ...          NaN
# 141  Osrednjeslovenska  LjubljanaCenter          Center  ...          NaN
# 142  Osrednjeslovenska  LjubljanaCenter          Center  ...          NaN
# ..                 ...              ...             ...  ...          ...
# 485      Obalno-kraška            Koper           Koper  ...          NaN
# 486      Obalno-kraška            Izola           Izola  ...          NaN
# 487      Obalno-kraška            Piran        Portorož  ...          NaN
# 488      Obalno-kraška            Koper           Koper  ...          NaN
# 622  Osrednjeslovenska  LjubljanaCenter          Center  ...          NaN
#
#     price/net_sizeM2  year_built year_ren  condition  en_eff  switch  \
# 10               NaN      1973.0      NaN        NaN       D     NaN
# 36               NaN      1900.0      NaN        NaN     NaN     NaN
# 140              NaN      1500.0      NaN        NaN     NaN     NaN
# 141              NaN      1500.0      NaN        NaN     NaN     NaN
# 142              NaN      1500.0      NaN        NaN     NaN     NaN
# ..               ...         ...      ...        ...     ...     ...
# 485              NaN      1960.0      NaN        NaN     NaN     NaN
# 486              NaN      1969.0      NaN        NaN     NaN     NaN
# 487              NaN      1980.0      NaN        NaN     NaN     NaN
# 488              NaN      2010.0      NaN        NaN      B1     NaN
# 622              NaN         NaN      NaN        NaN     NaN     NaN
#
#      park_spots  balcony  garden
# 10          NaN        1       0
# 36          NaN        0       1
# 140         NaN        0       0
# 141         NaN        0       0
# 142         NaN        0       0
# ..          ...      ...     ...
# 485         NaN        0       1
# 486         NaN        0       0
# 487           1        0       0
# 488           2        0       0
# 622           1        0       0
#
# [168 rows x 26 columns]

# %%
data_tfix.head()
# Out:
#      AD_ID  posted_date  posted_time  shown   price  currency  ptype  \
# 0  6523968           89          407     57  192000         0      0
# 1  6523894           89          402     29  134500         0      0
# 2  6523589           89          392     33   29500         0      0
# 3  6523431           89          385     34  120000         0      0
# 4  6523190           89          370     23  180000         0      0
#
#    l_region  l_2  l_3  ...  price/sizeM2  price/net_sizeM2  year_built  \
# 0        11    7  195  ...          2232              1828        2004
# 1         6   43   22  ...          4803              4637        1908
# 2         0  110  229  ...          2681              2681        1961
# 3        11   97  199  ...             0              1714        2020
# 4         6   42    9  ...          3396                 0        1988
#
#    year_ren  condition  en_eff  switch  park_spots  balcony  garden
# 0         0          5      18       0           0        0       0
# 1      2020          3      12       1           0        0       0
# 2         0          5      10       0           0        0       0
# 3         0          2       1       0           7        1       0
# 4         0          5      18       0           0        1       0
#
# [5 rows x 26 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Normalizer
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor, BaggingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
X_set = data_prep.drop('price', axis =1)
y_set = data_prep['price']

# %%
X_set.head()
#y_set.head()
# Out:
#      AD_ID posted_date posted_time shown currency       ptype  \
# 0  6523968  14.03.2021       18:49    57        €  cumulative
# 1  6523894  14.03.2021       18:39    29        €  cumulative
# 2  6523589  14.03.2021       18:07    33        €  cumulative
# 3  6523431  14.03.2021       17:47    34        €  cumulative
# 4  6523190  14.03.2021       17:16    23        €  cumulative
#
#             l_region                l_2               l_3  \
# 0          Savinjska              Celje     SlavkoŠlander
# 1  Osrednjeslovenska    LjubljanaCenter            Center
# 2          Gorenjska              Tržič             Tržič
# 3          Savinjska   SlovenskeKonjice  SlovenskeKonjice
# 4  Osrednjeslovenska  LjubljanaBežigrad          Bežigrad
#
#                     sits_in  ... price/sizeM2  price/net_sizeM2 year_built  \
# 0  V večstanovanjski stavbi  ...  2232.558140       1828.571429     2004.0
# 1  V večstanovanjski stavbi  ...  4803.571429       4637.931034     1908.0
# 2  V večstanovanjski stavbi  ...  2681.818182       2681.818182     1961.0
# 3  V večstanovanjski stavbi  ...          NaN       1714.285714     2020.0
# 4  V večstanovanjski stavbi  ...          NaN               NaN     1988.0
#
#    year_ren             condition  en_eff  switch  park_spots  balcony garden
# 0       NaN                   NaN     NaN     NaN         NaN        0      0
# 1    2020.0  Popolnoma opremljeno      EI     yes         NaN        0      0
# 2       NaN                   NaN       E     NaN         NaN        0      0
# 3       NaN          Neopremljeno      A2     NaN           7        1      0
# 4       NaN                   NaN     NaN     NaN         NaN        1      0
#
# [5 rows x 25 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def impute_cats(df):
    # Find the columns of object type along with their column index
    object_cols = list(df.select_dtypes(exclude=[np.number]).columns)
    object_cols_ind = []
    for col in object_cols:
        object_cols_ind.append(df.columns.get_loc(col))

    # Encode the categorical columns with numbers
    label_enc = LabelEncoder()
    encoders = {}
    
    
    for i in object_cols_ind:
        df.iloc[:,i] = label_enc.fit_transform(df.iloc[:,i])
        encoders[i] = label_enc
    return df, encoders

# %%
# Impute the missing values
data_imputed,encoders1 = impute_cats(data_tfix)
#print("Train Dtype counts: \n{}".format(data_imputed.dtypes.value_counts()))

# %%
data_imputed
# Out:
#         AD_ID  posted_date  posted_time  shown   price  currency  ptype  \
# 0     6523968           89          407     57  192000         0      0
# 1     6523894           89          402     29  134500         0      0
# 2     6523589           89          392     33   29500         0      0
# 3     6523431           89          385     34  120000         0      0
# 4     6523190           89          370     23  180000         0      0
# ...       ...          ...          ...    ...     ...       ...    ...
# 1183  2223586           65          419   3878   60000         0      0
# 1184  2217657          163          155   4143  164250         0      0
# 1185  2221094          163          149   4162  150015         0      0
# 1186  2222326          122          115   1362  170000         0      0
# 1187  2218508           92          247   1176   90000         0      0
#
#       l_region  l_2  l_3  ...  price/sizeM2  price/net_sizeM2  year_built  \
# 0           11    7  195  ...          2232              1828        2004
# 1            6   43   22  ...          4803              4637        1908
# 2            0  110  229  ...          2681              2681        1961
# 3           11   97  199  ...             0              1714        2020
# 4            6   42    9  ...          3396                 0        1988
# ...        ...  ...  ...  ...           ...               ...         ...
# 1183         7   51   22  ...           335                 0           0
# 1184         8   61  112  ...             0              1520        2019
# 1185         8   61  112  ...          1546                 0        2018
# 1186         6   44   62  ...          4047                 0        1963
# 1187        11  124  256  ...          1250                 0        1982
#
#       year_ren  condition  en_eff  switch  park_spots  balcony  garden
# 0            0          5      18       0           0        0       0
# 1         2020          3      12       1           0        0       0
# 2            0          5      10       0           0        0       0
# 3            0          2       1       0           7        1       0
# 4            0          5      18       0           0        1       0
# ...        ...        ...     ...     ...         ...      ...     ...
# 1183         0          5      12       0           0        0       0
# 1184         0          5       3       0           0        1       0
# 1185         0          5      12       0           0        0       0
# 1186      2013          5      12       0           0        0       0
# 1187      2015          5      18       0           0        0       0
#
# [1188 rows x 26 columns]

# %%
data_imputed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188 entries, 0 to 1187
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AD_ID             1188 non-null   int32
#  1   posted_date       1188 non-null   int32
#  2   posted_time       1188 non-null   int32
#  3   shown             1188 non-null   int32
#  4   price             1188 non-null   int64
#  5   currency          1188 non-null   int64
#  6   ptype             1188 non-null   int64
#  7   l_region          1188 non-null   int64
#  8   l_2               1188 non-null   int64
#  9   l_3               1188 non-null   int64
#  10  sits_in           1188 non-null   int64
#  11  lvl               1188 non-null   int64
#  12  t_lvl             1188 non-null   int32
#  13  flat_type         1188 non-null   int64
#  14  sizeM2            1188 non-null   int32
#  15  net_sizeM2        1188 non-null   int32
#  16  price/sizeM2      1188 non-null   int32
#  17  price/net_sizeM2  1188 non-null   int32
#  18  year_built        1188 non-null   int32
#  19  year_ren          1188 non-null   int32
#  20  condition         1188 non-null   int64
#  21  en_eff            1188 non-null   int64
#  22  switch            1188 non-null   int32
#  23  park_spots        1188 non-null   int32
#  24  balcony           1188 non-null   int32
#  25  garden            1188 non-null   int32
# dtypes: int32(15), int64(11)
# memory usage: 171.8 KB

# %%
encoders1
# Out:
# {}

# %%
plt.figure(figsize =(10, 10))
data_corr = data_imputed.corr()
sns.heatmap(data_corr,cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
train, test = train_test_split(data_imputed, test_size=0.2)
print(train)
# Out:
#        AD_ID  posted_date  posted_time  shown   price  currency  ptype  \
# 149  4381313           53          312   1826  159000         0      0
# 239  6442426           19          159   8639  200000         0      0
# 514  6367584          133          461   1093   39900         0      0
# 359  6385912          153           17    257   95000         0      0
# 875  4465999          150          427    382  145000         0      0
# ..       ...          ...          ...    ...     ...       ...    ...
# 669  6193936           11           29    501   65000         0      0
# 999  4690253          148          243    713   98000         0      0
# 297  6420998            1           37   1627  115000         0      0
# 640  6275681           75            7    784  189000         0      0
# 462  6384786          153           14     69  258000         0      0
#
#      l_region  l_2  l_3  ...  price/sizeM2  price/net_sizeM2  year_built  \
# 149         7   51   22  ...          1656              1407        1936
# 239         6   44   43  ...          2739                 0        1980
# 514         7   51   22  ...          2216                 0           0
# 359         7   51  220  ...             0                 0        1930
# 875        11   97  206  ...             0              1726        2019
# ..        ...  ...  ...  ...           ...               ...         ...
# 669         7   84  178  ...           500               500        1950
# 999        11    7   21  ...          1781              1781        1970
# 297         6   46  234  ...          3285              3484        1964
# 640         5   30   66  ...          2100              2100        1800
# 462         6   43  207  ...             0                 0        2009
#
#      year_ren  condition  en_eff  switch  park_spots  balcony  garden
# 149      2012          0      12       0           1        1       0
# 239         0          5       8       0           0        1       0
# 514         0          5      18       0           0        0       0
# 359         0          5      12       0           0        0       1
# 875         0          5       3       0           0        1       0
# ..        ...        ...     ...     ...         ...      ...     ...
# 669      1989          0      18       0           1        0       0
# 999      2015          0      18       0           0        0       0
# 297      2005          2      18       0           0        1       0
# 640      2015          5      18       0           0        0       0
# 462         0          5      18       0           2        0       0
#
# [950 rows x 26 columns]

# %%
xtrain = .drop['price']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-0e1169021009> in <module>
# ----> 1 xtrain = pd.train.drop['price']
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'train'
