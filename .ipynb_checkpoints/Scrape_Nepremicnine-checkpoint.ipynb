# %% [markdown]
# This is a notebook that I will use to define the functions to automate scraping from Nepremicnine.net.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
import pandas as pd
import numpy as np
import bs4
import lxml.etree as xml
import time
import datetime
from tqdm import tqdm
import random

# %% [markdown]
# Define path to the webdriver and define webdriver as driver.

# %%
PATH = '/Users/Asus/Downloads/chromedriver' # Defines where my cromedriver package is installed. Opens an automated Chrome window.
driver = webdriver.Chrome(PATH) # names webdriver as driver and assigns path. 
driver.quit() # closes the driver so the window is not always on.

# %%
# give base url to the site I want to scrape.
url = 'https://www.nepremicnine.net/oglasi-prodaja/'

# %%
driver = webdriver.Chrome(PATH) 
driver.get(url) # automatically opens Nepremicnine.net
# driver.quit() # this closes the window.

# %%
html = driver.page_source
webPage = bs4.BeautifulSoup(html, "lxml")

# %%
print(webPage.prettify())
# This is how the full HTML code looks like.
# Probably not needed, since we can select exactly what we want to look at in Chrome, but its there.
# Out:
# <html itemscope="" itemtype="http://schema.org/WebSite" lang="sl" style="display: block;" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="sl" http-equiv="content-language"/>
#   <meta content="D9C9544A6631C60218BF47FD618F42E5" name="msvalidate.01"/>
#   <meta content="IE=EDGE" http-equiv="X-UA-Compatible"/>
#   <meta content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" name="SKYPE_TOOLBAR"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <title>
#    Prodaja nepremičnin | NEPREMICNINE.net
#   </title>
#   <meta content="prodaja nepremičnin" name="Keywords"/>
#   <meta content="Rezultati iskanja nepremičnin: Prodaja nepremičnin na Nepremicnine.net" name="Description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="https://nepremicnine.click" rel="dns-prefetch"/>
#   <link href="https://nepremicnine.click" rel="preconnect"/>
#   <link href="https://www.nepremicnine.net" rel="dns-prefetch"/>
#   <link href="https://www.nepremicnine.net" rel="preconnect"/>
#   <link href="https://connect.facebook.net" rel="dns-prefetch"/>
#   <link href="https://connect.facebook.net" rel="preconnect"/>
#   <link href="https://ssl.google-analytics.com" rel="dns-prefetch"/>
#   <link href="https://ssl.google-analytics.com" rel="preconnect"/>
#   <meta content="https://www.nepremicnine.net/images/nepremicnine-net.jpg" property="og:image"/>
#   <meta content="Rezultati iskanja nepremičnin: Prodaja nepremičnin na Nepremicnine.net" property="og:description"/>
#   <meta content="Prodaja nepremičnin | NEPREMICNINE.net" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <link href="/images/icon_n.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link as="style" href="/styles.min.css?v=release_1.3.020&amp;r=10" media="all" rel="stylesheet" type="text/css"/>
#   <script async="" crossorigin="anonymous" src="https://connect.facebook.net/sl_SI/sdk.js?hash=0853fac51e97a049dae117a0855caa5f&amp;ua=modern_es6">
#   </script>
#   <script id="facebook-jssdk" src="//connect.facebook.net/sl_SI/sdk.js#xfbml=1&amp;version=v2.8&amp;appId=218433478210947">
#   </script>
#   <script async="" src="https://ssl.google-analytics.com/ga.js" type="text/javascript">
#   </script>
#   <script src="/scripts.min.js?v=release_1.3.020&amp;r=11" type="text/javascript">
#   </script>
#   <link as="style" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.6.1/css/font-awesome.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <link as="style" href="https://code.jquery.com/ui/1.12.1/themes/base/jquery-ui.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <script async="" src="https://cdnjs.cloudflare.com/ajax/libs/peity/3.3.0/jquery.peity.min.js">
#   </script>
#   <script async="" src="https://code.jquery.com/ui/1.12.1/jquery-ui.min.js">
#   </script>
#   <script type="text/javascript">
#    var ok_swiffy_isLoaded = 1; // variable used in nepremicnine.click to prevent multiple load of swiffy.js
#
#     $(document).ready(function() {
#     if (self == top) {
#             document.documentElement.style.display = 'block';
#     } else {
#             //document.documentElement.style.display = 'none';
#             $('body').html('<h1>Licenca iskalnika je potekla!</h1>').attr('style', 'background:none;');
#             window.top.location.href = 'https://www.nepremicnine.net/'
#     }
#
#         $('.prot').bind('contextmenu', function(e) {
#             return false;
#         });
#     });
#
#     $(document).ready(function(){
#         $("body").keypress(function(e){
#             if (e.which == 110 ) {
#                 if ( !$("input, textarea, select").is(":focus") ) {
#                     $("#hitroiskanje").focus();
#                     var el = $("#hitroiskanje").get(0);
#                     var elemLen = el.value.length;
#                     el.selectionStart = elemLen;
#                     el.selectionEnd = elemLen;
#                     e.defaultPrevented();
#                 }
#             }
#         });
#     });
#         // /* AS: search suggestion */
#         $(document).ready(function(){
#
#             if ($( "#hitroiskanje" ).is(':visible'))
#             {
#                 $(function() {
#                     var cache = {},
#                         lastXhr;
#                     $( "#hitroiskanje" ).appendTo("#hitroiskanje").autocomplete({
#                         minLength: 0,
#                         source: function( request, response ) {
#                             var term = request.term;
#
#                             if ( term in cache ) {
#                                 response( cache[ term ] );
#                                 return;
#                             }
#
#                             lastXhr = $.getJSON( "/jq/facet-suggest.php", request, function( data, status, xhr ) {
#                                 cache[ term ] = data;
#
#                                 if ( xhr === lastXhr ) {
#                                     response( data );
#                                 }
#                             });
#                         }
#                     });
#                 });
#             }
#             else
#             {
#                 $(function() {
#                     var cache = {},
#                         lastXhr;
#                     $( "#m-hitroiskanje" ).appendTo("#m-hitroiskanje").autocomplete({
#                         minLength: 0,
#                         source: function( request, response ) {
#                             var term = request.term;
#
#                             if ( term in cache ) {
#                                 response( cache[ term ] );
#                                 return;
#                             }
#
#                             lastXhr = $.getJSON( "/jq/facet-suggest.php", request, function( data, status, xhr ) {
#                                 cache[ term ] = data;
#
#                                 if ( xhr === lastXhr ) {
#                                     response( data );
#                                 }
#                             });
#                         }
#                     });
#                 });
#             }
#         });
#
#                 $(document).ready(function(){
#             $.ajax({
#                 url: "/jq/c.php",
#                 data: '' , //{ cookie : $.cookie('IP') }, // data to send to above script page if any
#                 async: false,
#                 cache: false,
#                 error: function(data){
#                     //alert('ERR: ' + data);
#                     $("#toperr").css("display", "block").append('<div class="msgE">Nimate omogočenih piškotkov (cookies). Uporaba je omejena.</div>')
#                 },
#                 success: function(data){
#                     if (data != '') {
#                         //$("#nocookie div").removeClass('msgE').addClass('msgI');
#                         //$("#nocookie div").replaceWith('<div class="msgI">Pozdravljeni na strani Nepremicnine.net.</div>')
#                     } else {
#                         $("#toperr").css("display", "block").append('<div class="msgE">Nimate omogočenih piškotkov (cookies). Uporaba je omejena.</div>')
#                     }
#
#                 }
#             })
#         });
#
#         jQuery(function($) {
#             $("a.fav").click(function(e){
#                 e.defaultPrevented(); // this will prevent the anchor tag from going the user off to the link
#                 var bookmarkUrl = this.href;
#                 var bookmarkTitle = 'Prodaja nepremičnin | NEPREMICNINE.net';
#                 if (navigator.userAgent.toLowerCase().indexOf('chrome') > -1) {
#                     alert("This function is not available in Google Chrome. Click the star symbol at the end of the address-bar or hit Ctrl-D (Command+D for Macs) to create a bookmark.");
#                 } else if (window.sidebar) { // For Mozilla Firefox Bookmark
#                     window.sidebar.addPanel(bookmarkTitle, bookmarkUrl,"");
#                 } else if( window.external || document.all) { // For IE Favorite
#                     window.external.AddFavorite( bookmarkUrl, bookmarkTitle);
#                 } else if(window.opera) { // For Opera Browsers
#                     $("a.bookmark").attr("href",bookmarkUrl);
#                     $("a.bookmark").attr("title",bookmarkTitle);
#                     $("a.bookmark").attr("rel","sidebar");
#                 } else { // for other browsers which does not support
#                     alert('Your browser does not support this bookmark action');
#                     return false;
#                 }
#             });
#         });
#
# //	$(document).ready(function(){
# // example uses the selector "input" with the class "auto" & no options passed
# //		jQuery(function($) {
# //			$('input.numeric').autoNumeric();
# //		});
#
#         // example uses the selector "input" with the class "auto" & with options passed
#         // See details below on allowed options
#         jQuery(function($) {
#             $('input.numeric').autoNumeric({aSep: '.', aDec: ','});
#             $('input.intnum').autoNumeric('init', {aSep: '.', aDec: ',', mDec: 0, aForm:false});
#             $('input.yearnum').autoNumeric({aSep: '', aDec: ',', mDec: 0, vMin: '0', vMax: '2022'});
#         });
#
#         $(document).ready (function () {
#             $('.jq-confirm').click (function () {
#                 return confirm ($(this).attr ("title") + "?") ;
#             }) ;
#
#             $('.jq-confirm-delete').click (function (e) {
#                 e.preventDefault();
#                 var url = $(this).attr('href');
#                 if (confirm ($(this).attr ("title")))
#                 {
#
#                     var ogl_cnt = parseInt($('.ogl-num').html());
#                     $('.ogl-num').each(function( index ) {
#                         $(this).text(ogl_cnt -1);
#                     });
#
#                     if ($(this).data("active") == 't')
#                         $('#vpis-stat td.cnt_ogl_t').html(parseInt($('#vpis-stat td.cnt_ogl_t').html() - 1));
#                     else
#                         $('#vpis-stat td.cnt_ogl_f').html(parseInt($('#vpis-stat td.cnt_ogl_f').html() - 1));
#
#                     $.get( url, function( data ) {
#                         //$( ".result" ).html( data );
#                     });
#                     $(this).closest('.oglas').slideUp('slow', function()
#                     {
#                         alert('Oglas je bil uspešno izbrisan.');
#                     });
#
#                 }
#             }) ;
#         }) ;
# //	}) ;
#
#     //slider zgoraj - moje nepremicnine
#     jQuery(function($) {
#         $(document).ready(function() {
#             $("a.btn-slide").mouseover(function() {
#                 $("#top-panel").stop(true, true).slideDown("fast");
#                 $(this).addClass("active");
#             });
#             $("#moje-nep").mouseleave(function() {
#                 if ( !$('#moje-nep input[type=text]').is(":focus") ) {
#                     $("#top-panel").delay(1000).slideUp("slow");
#                     $(this).removeClass("active");
#                 }
#             });
#         });
#         $(".flogin").bind("keyup change", function () {
#           $(this).val(function(i, v) { return v.replace(/  /g," "); });
#         });
#
#         $(document).bind('click', function(e) {
#             if( $(e.target).closest('#moje-nep').length === 0 ) {
#                 $("#top-panel").delay(1000).slideUp("slow");
#             }
#         });
#     });
#
#             $('<img src="/images/iskalnik.png"/>');
#
#         jQuery(function($) {
#             $(document).ready(function() {
#                 $("#fqrun").click(function() {
#                     $("li.iskalnik").addClass("open");
#                      $("#header").css('z-index', 500);
#                     $(".iskalnik ul").stop(true, true).slideDown("fast");
#                 });
#                 $("li.iskalnik").mouseover(function() {
#                      $("#header").css('z-index', 500);
#                     $(".iskalnik ul").stop(true, true).slideDown("fast");
#                     $(this).addClass("open");
#                 });
#                 $("li.iskalnik").mouseleave(function() {
#                     if ($('.iskalnik input[type=text]').is(":focus")) {
#                         $('input[type=text]').focus(function(){
#                             $(this).css({'background-color' : '#FCC'});
#                         });
#                         $('input[type=text]').blur(function(){
#                             $(this).css({'background-color' : '#fff'});
#                         });
#                     } else {
#                         if( /Android|webOS|iPhone|iPad|iPod|BlackBerry/i.test(navigator.userAgent) == false ) {
#                             $(".iskalnik ul").delay(500).slideUp("slow", function(){
#                                  $("#header").css('z-index', 300);
#                             });
#                         }
#                     }
#                     $(".iskalnik select").mouseleave(function(event){
#                         event.stopPropagation();
#                     });
#                     //$(this).removeClass("open");
#                 });
#
#                 $(document).bind('click', function(e) {
#                     if( $(e.target).closest('li.iskalnik.open').length === 0 && $(e.target).closest('#moje-nep').length === 0 ) {
#                         $("li.iskalnik.open ul").delay(500).slideUp("slow", function(){
#                             $("#header").css('z-index', 300);
#                         });
#                         $("#top-panel").delay(1000).slideUp("slow");
#                   }
#                 });
#
#             });
#         });
#
#
#
#     function rSel (r) {
#         $.post("/jq/r-sel.php", {id:r,rsel:'0'}, function(data) {
#             $("select#NOr").html(data);
#             $("select#NOr").removeAttr("disabled");
#         }).done(function(){serialize_search();});
#     }
#
#     $(function(){
#         $('input:radio[name=d]').change(function() {
#             $("select#NOr").attr("disabled","disabled");
#             $("select#NOr").html("<option>nalagam...</option>");
#
#             $("select#NOue1").attr("disabled","disabled");
#             $("select#NOue1").html("<option>nalagam...</option>");
#
#             var id = $(this).val();
#
#             $.post("/jq/r-sel.php", {id:id,rsel:'0'}, function(data) {
#                 $("select#NOr").html(data);
#                 $("select#NOr").removeAttr("disabled");
#             }).done(function(){
#                 /*mobile only*/
#                 if ($('.NOue').is(':visible')) {
#                     var id = $("select#NOr").val();
#                     $.post("/jq/ue-sel.php", {id:id, input:'select'}, function(data) {
#                         $("select#NOue1").html(data);
#                         $("select#NOue1").removeAttr("disabled");
#                     }).done(function(){serialize_search();});
#                 }
#                 else {
#                     var select = $('#NOr>option');
#                     select[0].selected = true;
#         			serialize_search();
#                 }
#             });
#             //$('#NOr')[0].selectedIndex = 0;
#             /*var select = $('#NOr>option');
#             select[0].selected = true;
# 			serialize_search();*/
#         });
#
#
#         $('select#NOr').change(function() {
#             var id = $(this).val();
#
#             $("select#NOue1").attr("disabled","disabled");
#             $("select#NOue1").html("<option>nalagam...</option>");
#
#             $.post("/jq/ue-sel.php", {id:id, input:'select'}, function(data) {
#                 $("select#NOue1").html(data);
#                 $("select#NOue1").removeAttr("disabled");
#             }).done(function(){serialize_search();});
#         });
#
#     });
#
#     $(function(){
#         $('.uni.clr').click(function() {
#             var clr = $(this).attr('data');
#             var aClr = clr.split(',');
#
#             for(i = 0; i< aClr.length; i++){
#                 $( aClr[i]).val('');
#             }
#         })
#     });
#
#     $(function(){
#         $('#clr-cena').click(function() {
#             $("#NOc1").val('');
#             $("#NOc2").val('');
#         })
#     });
#
#     jQuery(function($) {
#         $(document).ready(function() {
#             $("#NOreset").click(function() {
# //			$('input:radio[value=197]').prop('checked', true);
#                 $("#NOp option:first").attr('selected','selected');
#                 $("#NOn option:first").attr('selected','selected');
#                 $("#NOr option:first").attr('selected','selected');
#                 $("#NOc1").val('');
#                 $("#NOc2").val('');
#                 $("#NOcm2 option:first").attr('selected','selected');
#                 $('input:radio[value=197]').trigger('click');
#                 //$.post('/NOpar.php', { name: 'value' });
#               //$('#NOsearch').submit();
#             });
#         });
#     });
#
#     $(document).ready(function()
#     {
#         $("input:text").focus(function()
#         {
#             if ($(this).val() == $(this)[0].title)
#             {
#                 $(this).removeClass("grey");
#                 $(this).val("");
#             }
#         });
#
#         $("input:text").blur(function()
#         {
#             if ($(this).val() == "")
#             {
#                 $(this).addClass("grey");
#                 $(this).val($(this)[0].title);
#             }
#         });
#
#         $("input:text").blur();
#     });
#
#     $(document).ready(function(e){
#         $(".form-kontakt").on("touchenter touchmove", function(){
#             $("html, body").bind(function(e){
#                 e.defaultPrevented();
#             });
#         });
#     });
#
#     window.mobileAndTabletcheck = function() {
#       var check = false;
#       (function(a){if(/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows ce|xda|xiino|android|ipad|playbook|silk/i.test(a)||/1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0,4)))check = true})(navigator.userAgent||navigator.vendor||window.opera);
#       return check;
#     }
#
#     $(document).ready(function(e){
#         $('.contact-tooltip').tooltipster({
#             theme: 'tooltipster-shadow',
#             contentAsHTML: true,
#             position: 'left',
#             interactive: true
#         });
#
#         if (mobileAndTabletcheck()){
#             $('.contact-tooltip').click(function(){
#                 return false;
#             });
#         }
#
#         //add possibility do display mobiel version
#         if (mobileAndTabletcheck() && $('#logo-m').is(':hidden') && $(".scrsz").width() < 1043) {
#             if (document.documentElement.lang == 'sl')
#                 var switchText = 'PREKLOPI NA MOBILNO VERZIJO';
#             else
#                 var switchText = 'MOBILE VERSION';
#             $('#all').after('<div class="use-mobile-version"><a href="?mobile">'+switchText+'</a></div>');
#         }
#     });
#   </script>
#   <link as="style" href="https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;500;700&amp;display=swaps" onload="this.onload=null;this.rel='stylesheet'" rel="stylesheet"/>
#   <noscript>
#    <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;500;700&amp;display=swap" rel="stylesheet"/>
#   </noscript>
#   <meta content="fdN5cF2yYubJLN0QzkOj99U-Zw0Xqs0epcAH5U0uty0" name="google-site-verification"/>
#   <style>
#    #cookieWarn {
# 		position:relative;
# 		z-index:1;
# 		background:#313131;
# 		min-height:50px;
# 		width:auto;
# 		padding: 0 10px;
# 		font-size:11px;
# 		text-align:center;
# 		border-bottom: 1px solid #888;
# 	}
# 	#cookieWarn .inner{
# 		width:auto;
# 		margin: 0 auto;
# 		color:#fff;
# 		padding:4px 0;
# 	}
# 	#cookieWarn .naslov {
# 		padding:4px 0;
# 		font-weight:bold;
# 	}
# 	#cookieWarn .fl {
# 		width:800px;
# 	}
# 	#cookieTermsagree {
#     display: inline-block;
#     color: #fff;
#     text-decoration: none;
#     background: #222;
#     padding: 4px 10px;
# 		border: 1px solid rgb(85, 85, 85);
#     border-radius: 3px 3px 3px 3px;
#     box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.25);
#     text-shadow: 0px -1px 0px rgba(0, 0, 0, 0.35);
#     transition: background 0.25s ease-in 0s;
# 		cursor:pointer;
# }
#   </style>
#   <script>
#    jQuery(function() {
#
#   $.fn.cookieChecker = function(options) {
#
#     //maintain chainability
#     return this.each(function() {
#
# 			// Create some defaults, extending them with any options that were provided
# 			var settings = $.extend( {
# 				'cookieName': 'cookieOK',
# 				'msgFile'   : '/ext/cookieOK.php',
# 				'duration'   : '3'
# 			}, options);
#
# 			var cName = settings.cookieName;
# 			var msgFile = settings.msgFile;
# 			var duration = Number(settings.duration);
#
# 			//check for the cookie
# 			function readCookie(name) {
# 				var nameEQ = name + "=";
# 				var ca = document.cookie.split(';');
# 					for(var i=0;i < ca.length;i++) {
# 						var c = ca[i];
# 						while (c.charAt(0)==' ') c = c.substring(1,c.length);
# 						if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
# 					}
# 				return null;
# 			}
#
#
# 		if (readCookie(cName) != null){
# 			//console.info('cookies present');
# 		} else {
# //			$('#bar-top-wrapper').append($('<div id="cookieWarn"></div'));
# 			$('#toperr').prepend($('<div id="cookieWarn"></div'));
# 			$('#cookieWarn').load(msgFile, function(){
# 				$(this).slideDown();
# 				$('#cookieTermsagree').on('click', function(){
# 				// create one year duration cookie
# 				var theDate = new Date();
# 				var oneYearLater = new Date( theDate.getTime() + (31536000000 * duration));
# 				var expiryDate = oneYearLater.toGMTString();
# 				document.cookie = cName+'=1;expires='+expiryDate+';path=/';
# 				$('#cookieWarn').slideUp('fast',function(){
# 					$('#cookieWarn').empty().remove();
# 				});
# 				});
# 			});
# 		};
#
#   // end chainability
#   });
#
#   // end cookieChecker
#   }
#
#   // end plugin
# });
#
# 	$(document).ready(function(){
# 		$('body').cookieChecker();
# 	});
#   </script>
#   <style>
#    /*
# #ad-bg{position:fixed;top:0;left:50%;z-index:1}
# #ad-bg .ad-bg-pos{z-index:1;position:relative;left:-50%}
# #ad-bg .ad-bg-pos iframe{margin-top:23px;position:fixed;top:50%;left:50%;min-width:200%;min-height:100%;width:auto;height:auto;z-index:-100;-ms-transform:translateX(-50%) translateY(-50%);-moz-transform:translateX(-50%) translateY(-50%);-webkit-transform:translateX(-50%) translateY(-50%);transform:translateX(-50%) translateY(-50%)}
# */
#   </style>
#   <script async="" src="//nepremicnine.click/www/delivery/asyncjs.php">
#   </script>
#   <script type="text/javascript">
#    // Preloader
# $(window).on('load resize', function() {
#     $('#preloader').fadeOut(0);
#     $('body').css({'overflow':'visible'});
# })
#
# window.middle_h_screen = (screen.width/2)-300;
# window.middle_v_screen = (screen.height/2)-175;
#
# function popupCenter(url, title, w, h) {
#     // Fixes dual-screen position Most browsers Firefox
#     var dualScreenLeft = window.screenLeft != undefined ? window.screenLeft : screen.left;
#     var dualScreenTop = window.screenTop != undefined ? window.screenTop : screen.top;
#     width = window.innerWidth ? window.innerWidth : document.documentElement.clientWidth ? document.documentElement.clientWidth : screen.width;
#     height = window.innerHeight ? window.innerHeight : document.documentElement.clientHeight ? document.documentElement.clientHeight : screen.height;
#
#     var left = ((width / 2) - (w / 2)) + dualScreenLeft;
#     var top = ((height / 2) - (h / 2)) + dualScreenTop;
#     var newWindow = window.open(url, title, 'scrollbars=yes, width=' + w + ', height=' + h + ', top=' + top + ', left=' + left);
#
#     // Puts focus on the newWindow
#     if (window.focus) {
#     newWindow.focus();
#     }
# }
#
# // generate notes
# function generate(type, text, id) {
#
#             var n = noty({
#                 text        : text,
#                 type        : type,
#                 dismissQueue: true,
#                 layout      : 'bottomLeft',
#                 closeWith   : ['button'],
#                 theme       : 'relax',
#                 maxVisible  : 5,
#                 animation   : {
#                     open  : 'animated bounceInLeft',
#                     close : 'animated bounceOutLeft',
#                     easing: 'swing',
#                     speed : 500
#                 },
#                 callback: {
#                     onClose: function() {
#                         $.ajax({ url: '/jq/set_noted.php?id=' + id });
#                     }
#                 }
#             });
#             //console.log('html: ' + n.options.id);
#         }
#
#         function generateAll() {
#                         //generate('success');
#         }
#
#         $(document).ready(function () {
#
#             setTimeout(function() {
#                 generateAll();
#             }, 500);
#
#             setInterval(function() {
#                 var exclude = '?';
#                 $( ".notification-identifier" ).each(function( index ) {
#                     //console.log( index + ": " + $( this ).text() );
#                     exclude += 'exclude[]=' + $( this ).text() + '&';
#                 });
#                 $.get( "/jq/check_notifications.php" + exclude, function( data ) {
#                     $( "body" ).append( data );
#                 });
#             }, 1000 * 1000 * 1); // refresh every 10 minutes
#
#
#             var popup = false;
#             if (mobileAndTabletcheck() && $('#logo-m').is(':visible'))
#               popup = true;
#             $('#notification-bell a').webuiPopover({title:'<i class="fa fa-bell"></i> &nbsp; Obvestila',content:'Content',width:250,height:200,placement:'bottom-left',type:'async',url:'/jq/popover_notifications.php',cache:false,closeable:true,backdrop:popup});
#             $('#notification-message a').webuiPopover({title:'<i class="fa fa-envelope"></i> &nbsp; Sporočila',content:'Content',width:250,height:200,placement:'bottom-left',type:'async',url:'/jq/popover_messages.php',cache:false,closeable:true,backdrop:popup});
#
#             /*Search popup*/
#             $('.burger-nav-search > a').on('click', function () {
#                 $(".mobile-search").dialog({
#                     modal: true,
#                     title: 'Iskalnik',
#                     resizable: false,
#                     dialogClass: 'mobile-search-dialog',
#                     open: function( event, ui ) {
#                         var id = $('select#NOr').val();
#                         $.post("/jq/ue-sel.php", {id:id, input:'select'}, function(data) {
#                             $("select#NOue1").html(data);
#                         }).done(function(){serialize_search();});
#                     },
#                     buttons: {
#                         'Confirm': {
#                                 click: function () {
#                                     $('.ui-dialog .gumb.potrdi')[0].click();
#
#                                 },
#                                 text: 'Prikaži rezultate',
#                                 class: 'ui-ok'
#                             },
#                         "Cancel": {
#                                 click: function () {
#                                     $(this).dialog("destroy");
#                                 },
#                                 text: 'Zapri',
#                                 class: 'ui-cancle'
#                             }
#                       }
#                 });
#             });
#
#             // messaging
#             $(".inquiry-form").submit(function(event){
#                 event.preventDefault();
#                 event.stopPropagation();
#                 var id = $(this).find("#ad_id").val();
#                 var owner = $(this).find("#owner").val();
#                 var conversation = $(this).find("#conversation").val();
#                 var message = $(this).find("textarea").val();
#                 if (id && message){
#                     $.post( "/jq/message_send.php", { id: id, owner: owner, message: message, conversation: conversation }, function(data){
#                         //console.log(data.answer);
#                         if (data.answer == 'success')
#                         {
#                             var last_message = data.last_message;
#                             if ($("#conversation-" + conversation + " .messages-list li").length){
#                                 $("#conversation-" + conversation + " .messages-list li[key='" + (last_message*1 - 1) + "']").after('<li class="me" key="' + last_message + '"><img src="' + data.image + '" /><h4>' + data.username + '<br /><small> poslano ' + data.time + '</small></h4>' + data.message + '</li>');
#                             } else {
#                                 $("#conversation-" + conversation + " .messages-list").append('<li class="me" key="' + last_message + '"><img src="' + data.image + '" /><h4>' + data.username + '<br /><small> poslano ' + data.time + '</small></h4>' + data.message + '</li>');
#                             }
#                             $(".inquiry-form textarea").val('');
#                             $("#conversation-" + conversation + " .messages-list").perfectScrollbar('update');
#                             $("#conversation-" + conversation + " .messages-list").animate({ scrollTop: $("#conversation-" + conversation + " .messages-list")[0].scrollHeight}, 1000);
#                         }
#                     } );
#                 }
#                 //event.preventDefault();
#             });
#
#             // check for messages
#
#             // initialise scrollbar
#             if ($(".messages-list").length){
#                 $(".messages-list").perfectScrollbar();
#                 $('.messages-list').scrollTop($('.messages-list')[0].scrollHeight); // scroll to the bottom
#             }
#
#             if ($(".sender-info").length){
#                 $(".sender-info").each(function(index){
#                     var conversation_id = $(this).attr("conversation");
#                     var ad_id = $(this).attr("ad_id");
#                     var owner = $("#conversation-" + conversation_id + " #owner").val();
#                     $(this).click(function(){
#                         $(this).parent().addClass('shown');
#                         $(".conversation-container").not("#conversation-" + conversation_id).slideUp("fast");
#                         $(".conversation-ad-info").not("#conversation-info-" + conversation_id).slideUp("fast");
#
#                         if ($("#conversation-" + conversation_id).is(":visible"))
#                         {
#                             $("#conversation-" + conversation_id).slideUp('fast');
#                             $("#conversation-info-" + conversation_id).slideUp('fast');
#                         }
#                         else
#                         {
#
#                             $("#conversation-" + conversation_id).slideDown("fast", function(){
#                                 $("#conversation-" + conversation_id + " .messages-list").scrollTop($("#conversation-" + conversation_id + " .messages-list")[0].scrollHeight); // scroll to the bottom
#                             });
#                             $("#conversation-info-" + conversation_id).slideDown("fast");
#                         }
#                         $(this).removeClass("unread");
#                         $(this).parent().removeClass("unread");
#                         $.post( "/jq/message_update.php", { id: ad_id, owner: owner, conversation: conversation_id, update_change: 'read' }, function(data){
#                             //console.log(data.answer);
#                             if (data.answer == 'success')
#                             {
#                                 if (data.message_count)
#                                 {
#                                     if ($("#notification-message a").find('span').length)
#                                     {
#                                         $("#notification-message a").find('span').text(data.message_count);
#                                     } else {
#                                         $("#notification-message a").append('<span>' + data.message_count + '</span>');
#                                     }
#                                     $("#notification-message a").addClass('active');
#
#                                     $(".html-msg-count").text('(' + data.message_count + ')');
#                                 } else {
#                                     $("#notification-message a").find('span').remove();
#                                     $("#notification-message a").removeClass('active');
#
#                                     $(".html-msg-count").text('');
#                                 }
#                             }
#                         } );
#
#                     });
#                 });
#             }
#
#             // get message hash values
#             var hash_value = window.location.hash.substr(1);
#             if (hash_value){
#                 //alert(hash_value);
#                 if (hash_value.indexOf(":") > -1)
#                 {
#                     var split_value = hash_value.split(":")
#                     var action_value = split_value[0];
#                     var m_value = split_value[1];
#                 } else {
#                     if(hash_value.match(/^[0-9]+$/) != null)
#                     {
#                         //alert(hash_value);
#                         $([document.documentElement, document.body]).animate({
#                             scrollTop: $("#o-" + hash_value).offset().top -20
#                         }, 1000);
#                     }
#                     else
#                     {
#                         var action_value = hash_value;
#                         var m_value = 0;
#                     }
#                 }
#
#
#                 window.messages_updated = false;
#
#                 if (action_value == 'scroll_messages' && !m_value){
#                     $('html, body').animate({
#                         scrollTop: $("#get-info").offset().top
#                     }, 1000, 'swing', function(){
#                         if (!window.messages_updated)
#                         {
#                             window.messages_updated = true;
#                             var ad_id = $("#ad_id").val();
#                             var owner = $("#owner").val();
#                             var conversation_id = $("#conversation").val();
#
#                             $.post( "/jq/message_update.php", { id: ad_id, owner: owner, conversation: conversation_id, update_change: 'read' }, function(data){
#                                 if (data.answer == 'success')
#                                 {
#
#                                     if (data.message_count)
#                                     {
#                                         if ($("#notification-message a").find('span').length)
#                                         {
#                                             $("#notification-message a").find('span').text(data.message_count);
#                                         } else {
#                                             $("#notification-message a").append('<span>' + data.message_count + '</span>');
#                                         }
#                                         $("#notification-message a").addClass('active');
#
#                                         $(".html-msg-count").text('(' + data.message_count + ')');
#                                     } else {
#                                         $("#notification-message a").find('span').remove();
#                                         $("#notification-message a").removeClass('active');
#
#                                         $(".html-msg-count").text('');
#                                     }
#                                 }
#
#                             } );
#                         }
#                     });
#                 }
#
#                 if (action_value == 'scroll_messages' && m_value){
#                     var conversation_id = m_value;
#                     $("#sender-conversation-" + m_value).parent().addClass('shown');
#                     $('html, body').animate({
#                         scrollTop: $("#sender-conversation-" + m_value).offset().top
#                     }, 1000, 'swing', function(){
#                         $(".conversation-container").not("#conversation-" + conversation_id).slideUp("fast");
#                         $(".conversation-ad-info").not("#conversation-info-" + conversation_id).slideUp("fast");
#                         $("#conversation-" + conversation_id).slideDown("fast", function(){
#                             $("#conversation-" + conversation_id + " .messages-list").scrollTop($("#conversation-" + conversation_id + " .messages-list")[0].scrollHeight); // scroll to the bottom
#                             $("#sender-conversation-" + conversation_id).removeClass("unread");
#                             $("#sender-conversation-" + conversation_id).parent().removeClass("unread");
#                             var ad_id = $("#sender-conversation-" + conversation_id).attr('ad_id');
#                             var owner = $("#conversation-" + conversation_id + " #owner").val();
#
#                             if (!window.messages_updated)
#                             {
#                                 window.messages_updated = true;
#                                 $.post( "/jq/message_update.php", { id: ad_id, owner: owner, conversation: conversation_id, update_change: 'read' }, function(data){
#                                     //console.log(data.answer);
#                                     if (data.answer == 'success')
#                                     {
#                                         //alert('yay');
#                                         if (data.message_count)
#                                         {
#                                             if ($("#notification-message a").find('span').length)
#                                             {
#                                                 $("#notification-message a").find('span').text(data.message_count);
#                                             } else {
#                                                 $("#notification-message a").append('<span>' + data.message_count + '</span>');
#                                             }
#                                             $("#notification-message a").addClass('active');
#
#                                             $(".html-msg-count").text('(' + data.message_count + ')');
#                                         } else {
#                                             $("#notification-message a").find('span').remove();
#                                             $("#notification-message a").removeClass('active');
#
#                                             $(".html-msg-count").text('');
#                                         }
#                                     }
#
#                                 } );
#                             }
#                         });
#                         $("#conversation-info-" + conversation_id).slideDown("fast");
#                     });
#                 }
#             }
#         });
#
#         function update_read(element){
#             var ad_id = $(element).parent().find("#ad_id").val();
#             var owner = $(element).parent().find("#owner").val();
#             var conversation_id = $(element).parent().find("#conversation").val();
#             $.post( "/jq/message_update.php", { id: ad_id, owner: owner, conversation: conversation_id, update_change: 'read' }, function(data){
#                 if (data.answer == 'success')
#                 {
#                     if (data.message_count)
#                     {
#                         if ($("#notification-message a").find('span').length)
#                         {
#                             $("#notification-message a").find('span').text(data.message_count);
#                         } else {
#                             $("#notification-message a").append('<span>' + data.message_count + '</span>');
#                         }
#                         $("#notification-message a").addClass('active');
#
#                         $(".html-msg-count").text('(' + data.message_count + ')');
#                     } else {
#                         $("#notification-message a").find('span').remove();
#                         $("#notification-message a").removeClass('active');
#
#                         $(".html-msg-count").text('');
#                     }
#                 }
#             } );
#         }
#
#         function txt_auto_grow(element) {
#             element.style.height = "5px";
#             element.style.height = (element.scrollHeight)+"px";
#         }
#
#             var $dropdown = $('div.dropdownWrapper'),
#               $drpBtn   = $dropdown.find('div.dropdownLabel');
#
#         // search form
#         $( document ).ready(function() {
#             $("#NOsearch input").keyup(function(){
#                 serialize_search();
#             });
#             $("#NOsearch input[type='radio'], #NOsearch select").change(function(){
#                 serialize_search();
#             });
#
#             if ($("#naselja-izbira.scroll").length){
#                 $("#naselja-izbira").perfectScrollbar();
#             }
#         });
#
#         function serialize_search()
#         {
#             if (mobileAndTabletcheck() && $('#logo-m').is(':visible') && $(".mobile-search #NOsearch").length > 0)
#               var s_data = $(".mobile-search #NOsearch").serialize();
#             else
#               var s_data = $("#NOsearch").serialize();
#
#             $.post( "/jq/search.php?wpg=nepremicnine&" + s_data, function( data ) {
#               $("#NOsearch a.gumb.potrdi").attr('href', data);
#             });
#         }
#
#         function block_user(conversation_id, username)
#         {
#             var r = confirm("Želite blokirati uporabnika " + username + "?");
#             if (r == true) {
#                 $.get( "/jq/user_chat_actions.php?block&conversation_id=" + conversation_id, function( data ) {
#                     $("#sender-conversation-" + conversation_id).remove();
#                     $("#conversation-" + conversation_id).remove();
#                 });
#             }
#             return false;
#         }
#
#         function hide_conversation(conversation_id, username)
#         {
#             var r = confirm("Želite skriti pogovor z uporabnikom " + username + "?");
#             if (r == true) {
#                 $.get( "/jq/user_chat_actions.php?hide&conversation_id=" + conversation_id, function( data ) {
#                     $(".kontakt #sender-conversation-" + conversation_id).remove();
#                     $(".kontakt #conversation-" + conversation_id).remove();
#                     $("#inbox-" + conversation_id).addClass('hidden-message invisible');
#                 });
#             }
#             return false;
#         }
#   </script>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-15972954-1']);
#   _gaq.push(['_setDomainName', 'nepremicnine.net']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'https://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#     function trackOutboundLink(link, category) {
#         _gat._getTrackerByName()._trackEvent(category, link);
#     }
#   </script>
#   <meta content="NEPREMICNINE.net" itemprop="name"/>
#   <meta content="Največji slovenski nepremičninski portal" itemprop="description"/>
#   <link href="https://www.nepremicnine.net" itemprop="url"/>
#   <meta content="https://www.nepremicnine.net/images/nepremicnine-net-logo.jpg" itemprop="image"/>
#   <link href="https://www.nepremicnine.net/images/nepremicnine-net-logo.jpg" itemprop="thumbnailUrl"/>
#   <meta content="True" itemprop="isFamilyFriendly"/>
#   <link href="https://www.facebook.com/NEPREMICNINEnet-181757358510072/" itemprop="sameAs"/>
#   <script type="text/javascript">
#    <!--//<![CDATA[
#     if (isMobile.any)
#     {
#         var ox_u = 'https://nepremicnine.click/www/delivery/al.php?zoneid=90&layerstyle=geocities&align=right&padding=2&closetext=Zapri';
#         if (document.context) ox_u += '&context=' + escape(document.context);
#         document.write("<scr"+"ipt type='text/javascript' src='" + ox_u + "'></scr"+"ipt>");
#     }
# //]]>-->
#   </script>
#   <style data-fbcssmodules="css:fb.css.basecss:fb.css.dialog css:fb.css.iframewidget" type="text/css">
#    .fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# ...
#                                 if ($(this).hasClass('act')) {
#                                     $(this).removeClass('act');
#                                     filter_url = filter_url.replace(param, '');
#                                 }
#                                 else {
#                                     $(this).addClass('act actMob');
#                                     filter_url = filter_url.concat(param);
#                                 }
#
#                                 generate_filter_url(filter_url);
#                             }
#                         });
#                             /*Add generate url for custom Leto*/
#                             $('.more.year input[type=submit]').on('click', function(e) {
#                                 e.preventDefault();
#                                 var regex = /&l1=(.*?)[^;]*/igm;
#                                 filter_url = filter_url.replace(regex, '');
#
#                                 var val_from = $('.more.year input[name=l1]').val();
#                                 if (val_from == undefined)
#                                     val_from = '*';
#                                 var val_to = $('.more.year input[name=l2]').val();
#                                 if (val_to == undefined)
#                                     val_to = '*';
#
#                                 var param = '&l1=' + val_from.replace(/\./gmi, '') + '&l2=' + val_to.replace(/\./gmi, '') +';';
#                                 filter_url = filter_url.concat(param);
#
#                                 generate_filter_url(filter_url);
#                             });
#                             /*remove custom seted leto */
#                             $('.ui-dialog .ui-dialog-content #faceLeto .icon.clr.ur').on('click', function(e) {
#                                 e.preventDefault();
#
#                                 var regex = /&l1=(.*?)[^;]*/igm;
#                                 filter_url = filter_url.replace(regex, '');
#                                 var regex = /&l2=(.*?)[^;]*/igm;
#                                 filter_url = filter_url.replace(regex, '');
#
#                                 var default_vals = JSON.parse('["{\\"text\\":\\"do  - 1949\\",\\"val\\":\\"l1-*;l2-1949\\"}","{\\"text\\":\\"1950 - 1959\\",\\"val\\":\\"l1-1950;l2-1959\\"}","{\\"text\\":\\"1960 - 1969\\",\\"val\\":\\"l1-1960;l2-1969\\"}","{\\"text\\":\\"1970 - 1979\\",\\"val\\":\\"l1-1970;l2-1979\\"}","{\\"text\\":\\"1980 - 1989\\",\\"val\\":\\"l1-1980;l2-1989\\"}","{\\"text\\":\\"1990 - 1999\\",\\"val\\":\\"l1-1990;l2-1999\\"}","{\\"text\\":\\"2000 - 2009\\",\\"val\\":\\"l1-2000;l2-2009\\"}","{\\"text\\":\\"2010 - 2019\\",\\"val\\":\\"l1-2010;l2-2019\\"}","{\\"text\\":\\"2020 in ve\\u010d\\",\\"val\\":\\"l1-2020;l2-*\\"}"]');
#                                 $('#faceLeto').empty();
#                                 for (var i = 0, len = default_vals.length; i < len; ++i) {
#                                     var leto = JSON.parse(default_vals[i]);
#                                     $('#faceLeto').append('<li><a href="#" data-val="'+leto.val+'">'+leto.text+'</a></li>');
#                                 }
#
#                                 $("input[name='l1']").val('');
#                                 $("input[name='l2']").val('');
#
#                                 generate_filter_url(filter_url);
#                             });
#
#                         /*Add generate url for Datum vpisa*/
#                         $('#last').on('change', function(e) {
#                             e.preventDefault();
#
#                             var val = $(this).val();
#                             if (val == undefined) {
#                                 generate_filter_url(filter_url);
#                                 return;
#                             }
#
#                             var param = '&last='+val+';';
#                             filter_url = filter_url.concat(param);
#
#                             generate_filter_url(filter_url);
#                         });
#
#                         /*Add generate url for Vsi oglasi*/
#                         $('#f0').on('click', function(e) {
#                             var param = '&f=;';
#                             if($(this).is(":checked")){
#                                 filter_url = filter_url.concat(param);
#                             }
#                             else if($(this).is(":not(:checked)")){
#                                 filter_url = filter_url.replace(param, '');
#                             }
#                             generate_filter_url(filter_url);
#                         });
#
#                         /*Add generate url for Znižana cena*/
#                         $('#f1').on('click', function(e) {
#                             var param = '&f=1;';
#                             if($(this).is(":checked")){
#                                 filter_url = filter_url.concat(param);
#                             }
#                             else if($(this).is(":not(:checked)")){
#                                 filter_url = filter_url.replace(param, '');
#                             }
#                             generate_filter_url(filter_url);
#                         });
#
#                         /*Add generate url for Zasebna ponudba*/
#                         $('#f2').on('click', function(e) {
#                             var param = '&f=2;';
#                             if($(this).is(":checked")){
#                                 filter_url = filter_url.concat(param);
#                             }
#                             else if($(this).is(":not(:checked)")){
#                                 filter_url = filter_url.replace(param, '');
#                             }
#                             generate_filter_url(filter_url);
#                         });
#
#                         /*Add generate url for Studenti*/
#                         $('#student').on('click', function(e) {
#                             var regex = /&student(.*?)[^;]*/igm;
#                             filter_url = filter_url.replace(regex, '');
#
#
#                             var param = '&student=1;';
#                             if($(this).is(":checked"))
#                                 filter_url = filter_url.concat(param);
#
#                             generate_filter_url(filter_url);
#                         });
#                     });
#                 }
#             });
#         });
#     });
#       </script>
#       <div class="clearer">
#       </div>
#      </div>
#      <!-- /980 -->
#      <div class="clearer">
#      </div>
#     </div>
#     <div class="clearer">
#     </div>
#    </div>
#    <div id="footer-wrapper">
#     <div id="footer">
#      <div class="fmob">
#       <p class="f-comp">
#        <strong>
#         MEGANET d.o.o. © 1998 - 2021
#        </strong>
#       </p>
#       <hr/>
#       <div class="more_info_data">
#        <div class="block">
#         Kontakt: 03/567-91-10
#         <br/>
#         E-pošta:
#         <a class="nn" href="mailto:info@nepremicnine.net">
#          info@nepremicnine.net
#         </a>
#         <br/>
#         Delovni čas: pon.-pet., od 8:00 do 16:00
#         <br/>
#        </div>
#        <div class="block">
#         <strong>
#          Tehnična podpora:
#         </strong>
#         <br/>
#         E-pošta:
#         <a class="nn" href="mailto:podpora@nepremicnine.net">
#          podpora@nepremicnine.net
#         </a>
#        </div>
#       </div>
#       <ul class="mt-10">
#        <li>
#         <a href="/nepremicnine-rubrike.html">
#          <strong>
#           Rubrike oglasov
#          </strong>
#         </a>
#        </li>
#        <li>
#         <a href="/nepremicnine.html?q=menjava nepremičnine" title="menjava nepremičnine">
#          <strong>
#           Menjava nepremičnine
#          </strong>
#         </a>
#        </li>
#       </ul>
#       <ul>
#        <li>
#         <a href="/pogoji-uporabe.html">
#          Pogoji uporabe
#         </a>
#        </li>
#        <li>
#         <a href="/varstvo-podatkov.html">
#          Varstvo podatkov
#         </a>
#        </li>
#        <li>
#         <a href="/nepremicnine-oglasevanje.html">
#          Oglaševanje
#         </a>
#        </li>
#        <li>
#         <a href="/cookies.html">
#          O piškotkih
#         </a>
#        </li>
#        <li class="last">
#         <a href="/pomoc-in-svetovanje.html">
#          Pomoč
#         </a>
#        </li>
#        <li class="last">
#         <a href="/mobilna-aplikacija.html">
#          Mobilna aplikacija (Infonep)
#         </a>
#        </li>
#       </ul>
#       <div class="more_info">
#        <span>
#         kontakt
#        </span>
#        <i class="fa fa-envelope-o">
#        </i>
#       </div>
#      </div>
#      <div class="fdesk">
#       <div class="fl fleft">
#        <div class="block">
#         <strong>
#          MEGANET d.o.o. © 1998 - 2021
#         </strong>
#         <br/>
#         Kontakt: 03/567-91-10
#         <br/>
#         E-pošta:
#         <a class="nn" href="mailto:info@nepremicnine.net">
#          info@nepremicnine.net
#         </a>
#         <br/>
#         Delovni čas: pon.-pet., od 8:00 do 16:00
#         <br/>
#        </div>
#        <div class="spacer">
#        </div>
#        <div class="spacer">
#        </div>
#        <div class="block">
#         <strong>
#          Tehnična podpora:
#         </strong>
#         <br/>
#         E-pošta:
#         <a class="nn" href="mailto:podpora@nepremicnine.net">
#          podpora@nepremicnine.net
#         </a>
#        </div>
#       </div>
#       <div class="block fmiddle">
#        <ul>
#         <li>
#          <a href="https://www.nepremicnine.net" target="_blank">
#           www.nepremicnine.net
#          </a>
#         </li>
#         <li>
#          <a href="http://www.slonep.net" rel="noopener" target="_blank">
#           www.slonep.net
#          </a>
#         </li>
#         <li>
#          <a href="http://www.montazne-hise.net" rel="noopener" target="_blank">
#           www.montazne-hise.net
#          </a>
#         </li>
#         <li>
#          <a href="http://www.podsvojostreho.net" rel="noopener" target="_blank">
#           www.podsvojostreho.net
#          </a>
#         </li>
#         <li>
#          <a href="https://www.novogradnje.si" rel="noopener" target="_blank">
#           www.novogradnje.si
#          </a>
#         </li>
#         <li>
#          <a href="https://www.nepremicninar.com" rel="noopener" target="_blank">
#           www.nepremicninar.com
#          </a>
#         </li>
#         <li class="last">
#          <a href="http://www.samsvojmajstor.com" rel="noopener" target="_blank">
#           www.samsvojmajstor.com
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="fl fmiddle">
#        <div class="block">
#         <ul>
#          <li>
#           <a href="/nepremicnine-rubrike.html">
#            <strong>
#             Rubrike oglasov
#            </strong>
#           </a>
#          </li>
#          <li>
#           <a href="/nepremicnine.html?q=menjava nepremičnine" title="menjava nepremičnine">
#            <strong>
#             Menjava nepremičnine
#            </strong>
#           </a>
#          </li>
#          <li>
#           <a href="/pogoji-uporabe.html">
#            Pogoji uporabe
#           </a>
#          </li>
#          <li>
#           <a href="/varstvo-podatkov.html">
#            Varstvo podatkov
#           </a>
#          </li>
#          <li>
#           <a href="/nepremicnine-oglasevanje.html">
#            Oglaševanje
#           </a>
#          </li>
#          <li>
#           <a href="/cookies.html">
#            O piškotkih
#           </a>
#          </li>
#          <li class="last">
#           <a href="/pomoc-in-svetovanje.html">
#            Pomoč
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="fl fright">
#        <div class="block">
#         <ul>
#          <li>
#           <a href="/mobilna-aplikacija.html">
#            <strong>
#             Mobilna aplikacija (Infonep)
#            </strong>
#           </a>
#          </li>
#          <li>
#           <a href="/nepremicnine.html">
#            Podrobno iskanje
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="spacer">
#        </div>
#        <div class="spacer">
#        </div>
#        <div class="spacer">
#        </div>
#        <div class="spacer">
#        </div>
#        <div class="spacer">
#        </div>
#        <div class="spacer">
#        </div>
#        <div class="spacer">
#        </div>
#        <div class="spacer">
#        </div>
#        <div class="spacer">
#        </div>
#        <div class="block">
#         <ul>
#          <li>
#           <div class="fb-like fb_iframe_widget" data-action="like" data-colorscheme="dark" data-href="https://www.facebook.com/nepremicnineNET" data-layout="standard" data-share="false" data-size="large" data-width="220" fb-iframe-plugin-query="action=like&amp;app_id=218433478210947&amp;color_scheme=dark&amp;container_width=0&amp;href=https%3A%2F%2Fwww.facebook.com%2FnepremicnineNET&amp;layout=standard&amp;locale=sl_SI&amp;sdk=joey&amp;share=false&amp;size=large&amp;width=220" fb-xfbml-state="rendered">
#            <span style="vertical-align: bottom; width: 225px; height: 28px;">
#             <iframe allow="encrypted-media" allowfullscreen="true" allowtransparency="true" class="" data-testid="fb:like Facebook Social Plugin" frameborder="0" height="1000px" name="f26223a758aa0f8" scrolling="no" src="https://www.facebook.com/v2.8/plugins/like.php?action=like&amp;app_id=218433478210947&amp;channel=https%3A%2F%2Fstaticxx.facebook.com%2Fx%2Fconnect%2Fxd_arbiter%2F%3Fversion%3D46%23cb%3Df9c06e983893b%26domain%3Dwww.nepremicnine.net%26origin%3Dhttps%253A%252F%252Fwww.nepremicnine.net%252Ff15270ae15fccbc%26relation%3Dparent.parent&amp;color_scheme=dark&amp;container_width=0&amp;href=https%3A%2F%2Fwww.facebook.com%2FnepremicnineNET&amp;layout=standard&amp;locale=sl_SI&amp;sdk=joey&amp;share=false&amp;size=large&amp;width=220" style="border: none; visibility: visible; width: 225px; height: 28px;" title="fb:like Facebook Social Plugin" width="220px">
#             </iframe>
#            </span>
#           </div>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="fr tac">
#        <!--<div class="obisk">
# 			<script type="text/javascript" src="https://www.obisk.net/obisk/top.js"></script><script type="text/javascript">obisk(119,"g")</script>
# 		</div>-->
#       </div>
#      </div>
#     </div>
#     <div class="clearer">
#     </div>
#    </div>
#   </div>
#   <div class="scrsz" style="">
#   </div>
#   <script type="text/javascript">
#    $(".web-opis a").attr('target', '_blank');
#   </script>
#   <div id="cboxOverlay" style="display: none;">
#   </div>
#   <div class="" id="colorbox" role="dialog" style="display: none;" tabindex="-1">
#    <div id="cboxWrapper">
#     <div>
#      <div id="cboxTopLeft" style="float: left;">
#      </div>
#      <div id="cboxTopCenter" style="float: left;">
#      </div>
#      <div id="cboxTopRight" style="float: left;">
#      </div>
#     </div>
#     <div style="clear: left;">
#      <div id="cboxMiddleLeft" style="float: left;">
#      </div>
#      <div id="cboxContent" style="float: left;">
#       <div id="cboxTitle" style="float: left;">
#       </div>
#       <div id="cboxCurrent" style="float: left;">
#       </div>
#       <button id="cboxPrevious" type="button">
#       </button>
#       <button id="cboxNext" type="button">
#       </button>
#       <button id="cboxSlideshow">
#       </button>
#       <div id="cboxLoadingOverlay" style="float: left;">
#       </div>
#       <div id="cboxLoadingGraphic" style="float: left;">
#       </div>
#      </div>
#      <div id="cboxMiddleRight" style="float: left;">
#      </div>
#     </div>
#     <div style="clear: left;">
#      <div id="cboxBottomLeft" style="float: left;">
#      </div>
#      <div id="cboxBottomCenter" style="float: left;">
#      </div>
#      <div id="cboxBottomRight" style="float: left;">
#      </div>
#     </div>
#    </div>
#    <div style="position: absolute; width: 9999px; visibility: hidden; display: none; max-width: none;">
#    </div>
#   </div>
#   <ul class="ui-menu ui-widget ui-widget-content ui-autocomplete ui-front" id="ui-id-1" style="display: none;" tabindex="0">
#   </ul>
#   <div aria-live="assertive" aria-relevant="additions" class="ui-helper-hidden-accessible" role="status">
#   </div>
#  </body>
# </html>

# %% [markdown]
# We need to find what regions there are listed as options and how many pages of listings there are for each region.
# At this moment, I am only considering option of 'Selling', 'Renting' will come later.

# %%
# find the number of total pages. 
# print(webPage.find('div', id= 'pagination').find('span').text)
tpages = int(webPage.find('div', id= 'pagination').find('span').text)
tpages
# Out:
# 620

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6e09c162f4bc> in <module>
#       8     list1.append(ad.find('span', class_='vrsta').text)
#       9
# ---> 10     year_raw = ad.find('span', class_='atribut leto').text
#      11     year = int(year_raw.split(':')[-1])
#      12     list1.append(year)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# filtering out a year as an int, provided that 'atribut leto' is not None
for index, ad in enumerate(webPage.find_all('div', itemprop='item')):
    print({index}, (int(ad.find('a', class_='ikona-sh3 utility')['data-id'])))
    year_raw = ad.find('span', class_='atribut leto')
    year = int(year_raw.text.split(':')[-1]) if year_raw != None else print(np.nan)
    print(year)
    print('------------')
# Out:
# {0} 6389418
# 1978
# ------------
# {1} 6327522
# 1989
# ------------
# {2} 6141186
# 2010
# ------------
# {3} 6390803
# 1974
# ------------
# {4} 6327267
# 1984
# ------------
# {5} 6235186
# 1800
# ------------
# {6} 6387983
# 1800
# ------------
# {7} 6320190
# 2007
# ------------
# {8} 6272771
# nan
# None
# ------------
# {9} 6129674
# nan
# None
# ------------
# {10} 6389137
# 2021
# ------------
# {11} 6389254
# 2020
# ------------
# {12} 6389036
# 1981
# ------------
# {13} 6391861
# 1978
# ------------
# {14} 6379433
# 2005
# ------------
# {15} 6383557
# 2021
# ------------
# {16} 6352479
# 2020
# ------------
# {17} 6391479
# nan
# None
# ------------
# {18} 6347977
# 2019
# ------------
# {19} 6375238
# 2019
# ------------
# {20} 6361444
# 2020
# ------------
# {21} 6390447
# 2015
# ------------
# {22} 6269751
# 1995
# ------------
# {23} 6391755
# 2004
# ------------
# {24} 6107925
# 2009
# ------------
# {25} 6389090
# 2010
# ------------
# {26} 6387450
# 2021
# ------------
# {27} 6384740
# 2020
# ------------
# {28} 6356267
# 2020
# ------------
# {29} 6348081
# 2008
# ------------

# %%
# Starting DataFrame.
d = []
colNames = ['AdID','Title','Type', 'YearBuilt', 'Link', 'Seller', 'Size','SalePrice', 'lastUpdate']
data1 = pd.DataFrame(d, columns= colNames)
data1.shape
# Out:
# (0, 9)

# %%
data1 = data1.iloc[0:0]
data1
# Out:
# Empty DataFrame
# Columns: [AdID, Title, Type, YearBuilt, Link, Seller, Size, SalePrice, lastUpdate]
# Index: []

# %%
data1 = data1.iloc[0:0]
def readAds(webPage, df):
    
    for ad in webPage.find_all('div', itemprop='item'): 
        list1 = []

        list1.append(int(ad.find('a', class_='ikona-sh3 utility')['data-id']))

        list1.append(ad.find('span', class_='title').text)

        list1.append(ad.find('span', class_='vrsta').text)

        year_raw = ad.find('span', class_='atribut leto')
        year = int(year_raw.text.split(':')[-1]) if year_raw != None else np.nan
        list1.append(year)

        list1.append(ad.find('a', class_='slika')['href'])

        list1.append(ad.find('div', class_='prodajalec_o')['title'])

        size_raw = ad.find('span', class_='velikost').text
        size = float((size_raw.split(' ')[0]).replace('.', '').replace(',','.'))
        list1.append(size)

        price_raw = ad.find('span', class_='cena').text
        price = float(((price_raw.split(' ')[0]).replace('.', '')).replace(',', '.')) # remove dot separation and y decimal sep.
        list1.append(price)

        #date when it gets appended ot the list
        date = datetime.datetime.now()
        list1.append(date)

        dfx = pd.DataFrame(list1)
        df_len = len(df)
        df.loc[df_len] = dfx
    return df

# %%
# testing if the links are full
for link in tqdm(data1['Link']): print(link)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 7521.17it/s]
# /oglasi-prodaja/apno-hisa_6389418/
# /oglasi-prodaja/begunje-na-gorenjskem-pocitniski-objekt_6327522/
# /oglasi-prodaja/benedikt-stanovanje_6141186/
# /oglasi-prodaja/bezigrajski-dvor-plava-laguna-stanovanje_6390803/
# /oglasi-prodaja/bled-stanovanje_6327267/
# /oglasi-prodaja/bled-poslovni-prostor_6235186/
# /oglasi-prodaja/bodesce-hisa_6387983/
# /oglasi-prodaja/brezovica-pri-ljubljani-hisa_6320190/
# /oglasi-prodaja/brezovica-pri-ljubljani-sredisce-brezovice-posest_6272771/
# /oglasi-prodaja/britof-posest_6129674/
# /oglasi-prodaja/brtonigla-hisa_6389137/
# /oglasi-prodaja/brzac-hisa_6389254/
# /oglasi-prodaja/bs-3-stanovanje_6389036/
# /oglasi-prodaja/btc-balkon-dvigalo-nova-fasada-stanovanje_6391861/
# /oglasi-prodaja/btc-leskoskova-poslovni-prostor_6379433/
# /oglasi-prodaja/celje-stanovanje_6383557/
# /oglasi-prodaja/celje-hisa_6352479/
# /oglasi-prodaja/celje-hisa_6391479/
# /oglasi-prodaja/celje-center-glazija-stanovanje_6347977/
# /oglasi-prodaja/celje-center-glazija-stanovanje_6375238/
# /oglasi-prodaja/celje-hudinja-stanovanje_6361444/
# /oglasi-prodaja/cizici-stanovanje_6390447/
# /oglasi-prodaja/crnomelj-zadruzna-poslovni-prostor_6269751/
# /oglasi-prodaja/crnuce-stanovanje_6391755/
# /oglasi-prodaja/crnuce-brnciceva-ulica-31-poslovni-prostor_6107925/
# /oglasi-prodaja/divaca-na-severnem-robu-naselja-hisa_6389090/
# /oglasi-prodaja/dobrava-pri-konjicah-hisa_6387450/
# /oglasi-prodaja/dobrava-pri-sticni-hisa_6384740/
# /oglasi-prodaja/dobrinj-hisa_6356267/
# /oglasi-prodaja/dobrinj-cizici-stanovanje_6348081/

# %%
data2 = readAds(webPage,data1)
data2
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#        AdID                                        Title               Type  \
# 0   6389418                                         APNO               Hiša
# 1   6327522                        BEGUNJE NA GORENJSKEM  Počitniški objekt
# 2   6141186                                     BENEDIKT         Stanovanje
# 3   6390803               BEŽIGRAJSKI DVOR, PLAVA LAGUNA         Stanovanje
# 4   6327267                                         BLED         Stanovanje
# 5   6235186                                         BLED   Poslovni prostor
# 6   6387983                                      BODEŠČE               Hiša
# 7   6320190                      BREZOVICA PRI LJUBLJANI               Hiša
# 8   6272771  BREZOVICA PRI LJUBLJANI, SREDIŠČE BREZOVICE             Posest
# 9   6129674                                       BRITOF             Posest
# 10  6389137                                    BRTONIGLA               Hiša
# 11  6389254                                        BRZAC               Hiša
# 12  6389036                                         BS 3         Stanovanje
# 13  6391861          BTC, BALKON - DVIGALO - NOVA FASADA         Stanovanje
# 14  6379433                              BTC, LESKOŠKOVA   Poslovni prostor
# 15  6383557                                        CELJE         Stanovanje
# 16  6352479                                        CELJE               Hiša
# 17  6391479                                        CELJE               Hiša
# 18  6347977                      CELJE, CENTER - GLAZIJA         Stanovanje
# 19  6375238                      CELJE, CENTER - GLAZIJA         Stanovanje
# 20  6361444                               CELJE, HUDINJA         Stanovanje
# 21  6390447                                       ČIŽIĆI         Stanovanje
# 22  6269751                           ČRNOMELJ, ZADRUŽNA   Poslovni prostor
# 23  6391755                                       ČRNUČE         Stanovanje
# 24  6107925                   ČRNUČE, BRNČIČEVA ULICA 31   Poslovni prostor
# 25  6389090             DIVAČA, NA SEVERNEM ROBU NASELJA               Hiša
# 26  6387450                         DOBRAVA PRI KONJICAH               Hiša
# 27  6384740                           DOBRAVA PRI STIČNI               Hiša
# 28  6356267                                      DOBRINJ               Hiša
# 29  6348081                              DOBRINJ, ČIŽIĆI         Stanovanje
# 30  6389418                                         APNO               Hiša
# 31  6327522                        BEGUNJE NA GORENJSKEM  Počitniški objekt
# 32  6141186                                     BENEDIKT         Stanovanje
# 33  6390803               BEŽIGRAJSKI DVOR, PLAVA LAGUNA         Stanovanje
# 34  6327267                                         BLED         Stanovanje
# 35  6235186                                         BLED   Poslovni prostor
# 36  6387983                                      BODEŠČE               Hiša
# 37  6320190                      BREZOVICA PRI LJUBLJANI               Hiša
# 38  6272771  BREZOVICA PRI LJUBLJANI, SREDIŠČE BREZOVICE             Posest
# 39  6129674                                       BRITOF             Posest
# 40  6389137                                    BRTONIGLA               Hiša
# 41  6389254                                        BRZAC               Hiša
# 42  6389036                                         BS 3         Stanovanje
# 43  6391861          BTC, BALKON - DVIGALO - NOVA FASADA         Stanovanje
# 44  6379433                              BTC, LESKOŠKOVA   Poslovni prostor
# 45  6383557                                        CELJE         Stanovanje
# 46  6352479                                        CELJE               Hiša
# 47  6391479                                        CELJE               Hiša
# 48  6347977                      CELJE, CENTER - GLAZIJA         Stanovanje
# 49  6375238                      CELJE, CENTER - GLAZIJA         Stanovanje
# 50  6361444                               CELJE, HUDINJA         Stanovanje
# 51  6390447                                       ČIŽIĆI         Stanovanje
# 52  6269751                           ČRNOMELJ, ZADRUŽNA   Poslovni prostor
# 53  6391755                                       ČRNUČE         Stanovanje
# 54  6107925                   ČRNUČE, BRNČIČEVA ULICA 31   Poslovni prostor
# 55  6389090             DIVAČA, NA SEVERNEM ROBU NASELJA               Hiša
# 56  6387450                         DOBRAVA PRI KONJICAH               Hiša
# 57  6384740                           DOBRAVA PRI STIČNI               Hiša
# 58  6356267                                      DOBRINJ               Hiša
# 59  6348081                              DOBRINJ, ČIŽIĆI         Stanovanje
#
#    YearBuilt                                               Link  \
# 0       1978                 /oglasi-prodaja/apno-hisa_6389418/
# 1       1989  /oglasi-prodaja/begunje-na-gorenjskem-pocitnis...
# 2       2010       /oglasi-prodaja/benedikt-stanovanje_6141186/
# 3       1974  /oglasi-prodaja/bezigrajski-dvor-plava-laguna-...
# 4       1984           /oglasi-prodaja/bled-stanovanje_6327267/
# 5       1800     /oglasi-prodaja/bled-poslovni-prostor_6235186/
# 6       1800              /oglasi-prodaja/bodesce-hisa_6387983/
# 7       2007  /oglasi-prodaja/brezovica-pri-ljubljani-hisa_6...
# 8        NaN  /oglasi-prodaja/brezovica-pri-ljubljani-sredis...
# 9        NaN             /oglasi-prodaja/britof-posest_6129674/
# 10      2021            /oglasi-prodaja/brtonigla-hisa_6389137/
# 11      2020                /oglasi-prodaja/brzac-hisa_6389254/
# 12      1981           /oglasi-prodaja/bs-3-stanovanje_6389036/
# 13      1978  /oglasi-prodaja/btc-balkon-dvigalo-nova-fasada...
# 14      2005  /oglasi-prodaja/btc-leskoskova-poslovni-prosto...
# 15      2021          /oglasi-prodaja/celje-stanovanje_6383557/
# 16      2020                /oglasi-prodaja/celje-hisa_6352479/
# 17       NaN                /oglasi-prodaja/celje-hisa_6391479/
# 18      2019  /oglasi-prodaja/celje-center-glazija-stanovanj...
# 19      2019  /oglasi-prodaja/celje-center-glazija-stanovanj...
# 20      2020  /oglasi-prodaja/celje-hudinja-stanovanje_6361444/
# 21      2015         /oglasi-prodaja/cizici-stanovanje_6390447/
# 22      1995  /oglasi-prodaja/crnomelj-zadruzna-poslovni-pro...
# 23      2004         /oglasi-prodaja/crnuce-stanovanje_6391755/
# 24      2009  /oglasi-prodaja/crnuce-brnciceva-ulica-31-posl...
# 25      2010  /oglasi-prodaja/divaca-na-severnem-robu-naselj...
# 26      2021  /oglasi-prodaja/dobrava-pri-konjicah-hisa_6387...
# 27      2020   /oglasi-prodaja/dobrava-pri-sticni-hisa_6384740/
# 28      2020              /oglasi-prodaja/dobrinj-hisa_6356267/
# 29      2008  /oglasi-prodaja/dobrinj-cizici-stanovanje_6348...
# 30      1978                 /oglasi-prodaja/apno-hisa_6389418/
# 31      1989  /oglasi-prodaja/begunje-na-gorenjskem-pocitnis...
# 32      2010       /oglasi-prodaja/benedikt-stanovanje_6141186/
# 33      1974  /oglasi-prodaja/bezigrajski-dvor-plava-laguna-...
# 34      1984           /oglasi-prodaja/bled-stanovanje_6327267/
# 35      1800     /oglasi-prodaja/bled-poslovni-prostor_6235186/
# 36      1800              /oglasi-prodaja/bodesce-hisa_6387983/
# 37      2007  /oglasi-prodaja/brezovica-pri-ljubljani-hisa_6...
# 38       NaN  /oglasi-prodaja/brezovica-pri-ljubljani-sredis...
# 39       NaN             /oglasi-prodaja/britof-posest_6129674/
# 40      2021            /oglasi-prodaja/brtonigla-hisa_6389137/
# 41      2020                /oglasi-prodaja/brzac-hisa_6389254/
# 42      1981           /oglasi-prodaja/bs-3-stanovanje_6389036/
# 43      1978  /oglasi-prodaja/btc-balkon-dvigalo-nova-fasada...
# 44      2005  /oglasi-prodaja/btc-leskoskova-poslovni-prosto...
# 45      2021          /oglasi-prodaja/celje-stanovanje_6383557/
# 46      2020                /oglasi-prodaja/celje-hisa_6352479/
# 47       NaN                /oglasi-prodaja/celje-hisa_6391479/
# 48      2019  /oglasi-prodaja/celje-center-glazija-stanovanj...
# 49      2019  /oglasi-prodaja/celje-center-glazija-stanovanj...
# 50      2020  /oglasi-prodaja/celje-hudinja-stanovanje_6361444/
# 51      2015         /oglasi-prodaja/cizici-stanovanje_6390447/
# 52      1995  /oglasi-prodaja/crnomelj-zadruzna-poslovni-pro...
# 53      2004         /oglasi-prodaja/crnuce-stanovanje_6391755/
# 54      2009  /oglasi-prodaja/crnuce-brnciceva-ulica-31-posl...
# 55      2010  /oglasi-prodaja/divaca-na-severnem-robu-naselj...
# 56      2021  /oglasi-prodaja/dobrava-pri-konjicah-hisa_6387...
# 57      2020   /oglasi-prodaja/dobrava-pri-sticni-hisa_6384740/
# 58      2020              /oglasi-prodaja/dobrinj-hisa_6356267/
# 59      2008  /oglasi-prodaja/dobrinj-cizici-stanovanje_6348...
#
#                                         Seller      Size  SalePrice  \
# 0                              Zasebna ponudba    150.00   320000.0
# 1                      ABC nepremičnine d.o.o.    800.00  1300000.0
# 2                                   DUTB, d.d.     52.70    62900.0
# 3             QUDOS, center nepremičnin d.o.o.    119.00   323000.0
# 4                     Adut nepremičnine d.o.o.     96.10   150000.0
# 5                               K3 Kern d.o.o.    548.80  1100000.0
# 6                              Zasebna ponudba    300.00   290000.0
# 7                      ABC nepremičnine d.o.o.    495.00   399000.0
# 8                           Dajč & Dajč d.o.o.   1529.00      185.0
# 9                                   DUTB, d.d.  21939.00  1950000.0
# 10                            Universum d.o.o.    233.00   380000.0
# 11                          Alfa Elmas d.o.o.     168.45   415000.0
# 12                            Studio 68 d.o.o.     73.00   210000.0
# 13                       VIN inženiring d.o.o.     61.20   243700.0
# 14                    Mreža nepremičnin d.o.o.    123.00   202950.0
# 15                    Borza nepremičnin d.o.o.     85.10   180320.0
# 16  Bajtiga poslovanje z nepremičninami d.o.o.    107.00   109000.0
# 17                 KAPITOL posredovanje d.o.o.    450.00  1525000.0
# 18                ANSITRA, nepremičnine d.o.o.    115.20   252337.5
# 19                ANSITRA, nepremičnine d.o.o.    129.70   273355.0
# 20                          SGP Graditelj d.d.     56.40   137500.0
# 21                   Marvel Real Estate d.o.o.     58.00   132000.0
# 22                 Zavarovalnica Triglav, d.d.    571.00   350000.0
# 23                    Mreža nepremičnin d.o.o.    114.00   332000.0
# 24                    Salomon d.o.o. Ljubljana    722.80   790000.0
# 25         Ruj nepremičnine, Jernej Suša, s.p.    180.00   125000.0
# 26                 GEOSTAN Katja Leskovar s.p.    152.00   175000.0
# 27                      TRG NEPREMIČNIN d.o.o.    152.90   259000.0
# 28                                Vitus d.o.o.    101.07   295000.0
# 29                           Premium SM d.o.o.     64.00   112000.0
# 30                             Zasebna ponudba    150.00   320000.0
# 31                     ABC nepremičnine d.o.o.    800.00  1300000.0
# 32                                  DUTB, d.d.     52.70    62900.0
# 33            QUDOS, center nepremičnin d.o.o.    119.00   323000.0
# 34                    Adut nepremičnine d.o.o.     96.10   150000.0
# 35                              K3 Kern d.o.o.    548.80  1100000.0
# 36                             Zasebna ponudba    300.00   290000.0
# 37                     ABC nepremičnine d.o.o.    495.00   399000.0
# 38                          Dajč & Dajč d.o.o.   1529.00      185.0
# 39                                  DUTB, d.d.  21939.00  1950000.0
# 40                            Universum d.o.o.    233.00   380000.0
# 41                          Alfa Elmas d.o.o.     168.45   415000.0
# 42                            Studio 68 d.o.o.     73.00   210000.0
# 43                       VIN inženiring d.o.o.     61.20   243700.0
# 44                    Mreža nepremičnin d.o.o.    123.00   202950.0
# 45                    Borza nepremičnin d.o.o.     85.10   180320.0
# 46  Bajtiga poslovanje z nepremičninami d.o.o.    107.00   109000.0
# 47                 KAPITOL posredovanje d.o.o.    450.00  1525000.0
# 48                ANSITRA, nepremičnine d.o.o.    115.20   252337.5
# 49                ANSITRA, nepremičnine d.o.o.    129.70   273355.0
# 50                          SGP Graditelj d.d.     56.40   137500.0
# 51                   Marvel Real Estate d.o.o.     58.00   132000.0
# 52                 Zavarovalnica Triglav, d.d.    571.00   350000.0
# 53                    Mreža nepremičnin d.o.o.    114.00   332000.0
# 54                    Salomon d.o.o. Ljubljana    722.80   790000.0
# 55         Ruj nepremičnine, Jernej Suša, s.p.    180.00   125000.0
# 56                 GEOSTAN Katja Leskovar s.p.    152.00   175000.0
# 57                      TRG NEPREMIČNIN d.o.o.    152.90   259000.0
# 58                                Vitus d.o.o.    101.07   295000.0
# 59                           Premium SM d.o.o.     64.00   112000.0
#
#                    lastUpdate
# 0  2021-03-03 22:05:58.968810
# 1  2021-03-03 22:05:58.976756
# 2  2021-03-03 22:05:58.982739
# 3  2021-03-03 22:05:58.989720
# 4  2021-03-03 22:05:58.995739
# 5  2021-03-03 22:05:59.000729
# 6  2021-03-03 22:05:59.006715
# 7  2021-03-03 22:05:59.011700
# 8  2021-03-03 22:05:59.015652
# 9  2021-03-03 22:05:59.021672
# 10 2021-03-03 22:05:59.026659
# 11 2021-03-03 22:05:59.030650
# 12 2021-03-03 22:05:59.035636
# 13 2021-03-03 22:05:59.040622
# 14 2021-03-03 22:05:59.045572
# 15 2021-03-03 22:05:59.050595
# 16 2021-03-03 22:05:59.055583
# 17 2021-03-03 22:05:59.059572
# 18 2021-03-03 22:05:59.064557
# 19 2021-03-03 22:05:59.069544
# 20 2021-03-03 22:05:59.073533
# 21 2021-03-03 22:05:59.078523
# 22 2021-03-03 22:05:59.082509
# 23 2021-03-03 22:05:59.087496
# 24 2021-03-03 22:05:59.092485
# 25 2021-03-03 22:05:59.096472
# 26 2021-03-03 22:05:59.101459
# 27 2021-03-03 22:05:59.105448
# 28 2021-03-03 22:05:59.110437
# 29 2021-03-03 22:05:59.115423
# 30 2021-03-03 22:09:58.589452
# 31 2021-03-03 22:09:58.599426
# 32 2021-03-03 22:09:58.606408
# 33 2021-03-03 22:09:58.613429
# 34 2021-03-03 22:09:58.619414
# 35 2021-03-03 22:09:58.624395
# 36 2021-03-03 22:09:58.629382
# 37 2021-03-03 22:09:58.633371
# 38 2021-03-03 22:09:58.639373
# 39 2021-03-03 22:09:58.644360
# 40 2021-03-03 22:09:58.649350
# 41 2021-03-03 22:09:58.654335
# 42 2021-03-03 22:09:58.658323
# 43 2021-03-03 22:09:58.663309
# 44 2021-03-03 22:09:58.668297
# 45 2021-03-03 22:09:58.672291
# 46 2021-03-03 22:09:58.677272
# 47 2021-03-03 22:09:58.682260
# 48 2021-03-03 22:09:58.686250
# 49 2021-03-03 22:09:58.691237
# 50 2021-03-03 22:09:58.696222
# 51 2021-03-03 22:09:58.700212
# 52 2021-03-03 22:09:58.705198
# 53 2021-03-03 22:09:58.709190
# 54 2021-03-03 22:09:58.714173
# 55 2021-03-03 22:09:58.719166
# 56 2021-03-03 22:09:58.723156
# 57 2021-03-03 22:09:58.728136
# 58 2021-03-03 22:09:58.732126
# 59 2021-03-03 22:09:58.737113

# %%
# adding df of every page to the main df.
def addDF(mainDF, newDF):
    df = pd.concat([mainDF, newDF])
    return df

# %%
test1 = addDF(data2, data2)
test1.shape
# Out:
# (120, 9)

# %%
# test for generating new URLs
base_url = 'https://www.nepremicnine.net/oglasi-prodaja/'
for i in range(10):
    url = base_url + str(i)+'/'
    print(url)

# %%
driver = webdriver.Chrome(PATH) 
base_url = 'https://www.nepremicnine.net/oglasi-prodaja/'
base_df = data1.iloc[0:0]
df1 = df1.iloc[0:0]
print(base_df)
for i in tqdm(range(1,5)):
    url = base_url + str(i) + '/'
    driver.get(url)
    
    time.sleep(1 + random.randint(1,6)/10)
    html = driver.page_source
    webPage = bs4.BeautifulSoup(html, "lxml")
    
    df1 = readAds(webPage, data1)
    base_df.shape
    dfMain = addDF(base_df,df1)
# Out:
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
# Empty DataFrame
# Columns: [AdID, Title, Type, YearBuilt, Link, Seller, Size, SalePrice, lastUpdate]
# Index: []
#   0%|                                                                                            | 0/4 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-217-623ef11beedd> in <module>
#      12     webPage = bs4.BeautifulSoup(html, "lxml")
#      13
# ---> 14     df1 = readAds(webPage, data1)
#      15     base_df.shape
#      16     dfMain = addDF(base_df,df1)
#
# <ipython-input-216-5691fb1a36ef> in readAds(webPage, df)
#      33         dfx = pd.DataFrame(list1)
#      34         df_len = len(df)
# ---> 35         df.loc[df_len] = dfx
#      36     return df
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1624
#    1625             if missing:
# -> 1626                 self._setitem_with_indexer_missing(indexer, value)
#    1627                 return
#    1628
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    1858                         raise ValueError("cannot set a row with mismatched columns")
#    1859
# -> 1860                 value = Series(value, index=self.obj.columns, name=indexer)
#    1861
#    1862             self.obj._mgr = self.obj.append(value)._mgr
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     229             name = ibase.maybe_extract_name(name, data, type(self))
#     230
# --> 231             if is_empty_data(data) and dtype is None:
#     232                 # gh-17261
#     233                 warnings.warn(
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in is_empty_data(data)
#     594     is_none = data is None
#     595     is_list_like_without_dtype = is_list_like(data) and not hasattr(data, "dtype")
# --> 596     is_simple_empty = is_list_like_without_dtype and not data
#     597     return is_none or is_simple_empty
#     598
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df1.shape
# Out:
# (0, 9)

# %%
base_df
# Out:
# Empty DataFrame
# Columns: [AdID, Title, Type, YearBuilt, Link, Seller, Size, SalePrice, lastUpdate]
# Index: []

# %%
# Out:
# 0 +++ 0.5
# 1 +++ 0.6
# 2 +++ 0.1
# 3 +++ 0.5
# 4 +++ 0.2
# 5 +++ 0.5
# 6 +++ 0.4
# 7 +++ 0.6
# 8 +++ 0.2
# 9 +++ 0.4
